# %% [markdown]
# #Descrição do Programa

# %% [markdown]
# ## Visão Geral

# %% [markdown]
# O **AlfaScraps** é uma ferramenta desenvolvida para facilitar a análise de dados macroeconômicos e financeiros. Ele permite que o usuário acesse séries temporais de diversos indicadores de maneira simples, rápida e personalizada.
#
# A interface interativa no terminal possibilita que o usuário:
# - Selecione o tipo de dado desejado.
# - Defina o período de análise.
# - Exporte as informações para arquivos **.csv** para posterior análise.
#
# Esse programa foi projetado para atender tanto usuários iniciantes quanto especialistas em análise de dados.

# %% [markdown]
# ##Tecnologias Utilizadas

# %% [markdown]
# O **AlfaScraps** foi desenvolvido utilizando as seguintes tecnologias:
#
# - **Python 3.10+**: A principal linguagem utilizada, aproveitando seus recursos modernos para garantir desempenho e legibilidade.
# - **yfinance**: Biblioteca para coleta de dados financeiros, como ações e criptomoedas, diretamente de fontes confiáveis.
# - **python-bcb**: Usada para obter dados macroeconômicos diretamente do Banco Central do Brasil, essencial para a análise econômica.
# - **fredapi**: Interface com o FRED (Federal Reserve Economic Data), permitindo acesso aos dados macroeconômicos dos Estados Unidos.
# - **pandas**: Ferramenta fundamental para manipulação e análise de grandes volumes de dados.
# - **concurrent.futures**: Usada para otimização do desempenho por meio de execução paralela, permitindo buscas mais rápidas.
# - **Requests**: Utilizada para realizar web scraping e coletar dados de APIs como **brapi.dev** e **CoinGecko**.

# %% [markdown]
# ##Estrutura Geral do Código

# %% [markdown]
# * **Instalação de pacotes:** Primeira etapa para garantir que todas as dependências estejam corretas.
#
# * **Importação de bibliotecas:** Organização das bibliotecas utilizadas.
#
# * **Definição de dados:**
# Estrutura de dicionários contendo indicadores macroeconômicos, ações, commodities, criptomoedas e índices globais.
#
# * **Funções auxiliares:**
#
#   * Escolha do período de análise
#
#   * Criação de arquivos **.csv**
#
#   * Listagem de dados
#
#   * Interface de seleção interativa no terminal
#
# * **Módulo Principal:**
#
#   * Execução da interface de busca.
#
#   * Geração de arquivo .csv com as informações selecionadas.

# %% [markdown]
# ##Funcionalidades

# %% [markdown]
# * Buscar indicadores macroeconômicos brasileiros e internacionais.
#
# * Consultar ações da B3 separadas por tipo (ações ordinárias, preferenciais, BDRs, FIIs e ETFs).
#
# * Listar as principais criptomoedas disponíveis no mercado.
#
# * Exportar os dados buscados para arquivos **.csv**.
#
# * Interface amigável de terminal, permitindo navegação rápida.

# %% [markdown]
# ## Como Executar

# %% [markdown]
# 1. Clone o repositório ou copie o notebook.
#
# 2. Executar todas as células
#   * manualmente seguindo a ordem em que foram postas
#   * Caso esteja no Google Colab, selecione em **"Ambiente de execução"** a opção **"Executar tudo"**.
#
# 3. Siga as instruções do terminal na secção **Interface Principal** para buscar o dado desejado.

# %% [markdown]
# ##Organização da Busca

# %% [markdown]
# * As opções de busca estão organizadas em:
#
#   * Indicadores Macroeconômicos Brasileiros
#
#   * Indicadores Macroeconômicos dos EUA
#
#   * Commodities
#
#   * Índices Globais
#
#   * Ações da B3
#
#   * Criptomoedas
#
# * Podem ser visualizadas de forma mais detalhada na secção **Dados** e **Glossário**

# %% [markdown]
# ##Autor

# %% [markdown]
# João Vitor Figueiredo Villa -
# [LinkedIn](https://www.linkedin.com/in/jo%C3%A3o-vitor-figueiredo-villa-8323b8323/)

# %% [markdown]
# #Pacotes

# %% [markdown]
# ##Download dos pacotes

# %% [markdown]
# Na primeira vez que o código for executado no computador — ou após ficar muito tempo sem ser usado — é necessário instalar os pacotes indicados nas células desta seção.

# %%
# !pip install python-bcb
# Out:
# Collecting python-bcb
#   Downloading python_bcb-0.3.3-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: httpx>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from python-bcb) (0.28.1)
# Requirement already satisfied: lxml>=4.9.2 in /usr/local/lib/python3.11/dist-packages (from python-bcb) (5.4.0)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from python-bcb) (2.2.2)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.11/dist-packages (from python-bcb) (2.32.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.0->python-bcb) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.0->python-bcb) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.0->python-bcb) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.0->python-bcb) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.24.0->python-bcb) (0.16.0)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->python-bcb) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->python-bcb) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->python-bcb) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->python-bcb) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->python-bcb) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->python-bcb) (2.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->python-bcb) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.24.0->python-bcb) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.24.0->python-bcb) (4.13.2)
# Downloading python_bcb-0.3.3-py3-none-any.whl (19 kB)
# Installing collected packages: python-bcb
# Successfully installed python-bcb-0.3.3

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.11/dist-packages (0.2.56)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.0.2)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from yfinance) (4.3.7)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.11/dist-packages (from yfinance) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.11/dist-packages (from yfinance) (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (4.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)

# %%
# !pip install investpy
# Out:
# Collecting investpy
#   Downloading investpy-1.0.8.tar.gz (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 29.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting Unidecode>=1.1.1 (from investpy)
#   Downloading Unidecode-1.4.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: setuptools>=41.2.0 in /usr/local/lib/python3.11/dist-packages (from investpy) (75.2.0)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.11/dist-packages (from investpy) (2.0.2)
# Requirement already satisfied: pandas>=0.25.1 in /usr/local/lib/python3.11/dist-packages (from investpy) (2.2.2)
# Requirement already satisfied: lxml>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from investpy) (5.4.0)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.11/dist-packages (from investpy) (2.32.3)
# Requirement already satisfied: pytz>=2019.3 in /usr/local/lib/python3.11/dist-packages (from investpy) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.25.1->investpy) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.25.1->investpy) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22.0->investpy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22.0->investpy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22.0->investpy) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22.0->investpy) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=0.25.1->investpy) (1.17.0)
# Downloading Unidecode-1.4.0-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.8/235.8 kB 14.3 MB/s eta 0:00:00
# Building wheels for collected packages: investpy
#   Building wheel for investpy (setup.py) ... done
#   Created wheel for investpy: filename=investpy-1.0.8-py3-none-any.whl size=4481565 sha256=ad979d053bb59e832f313702ac4352472b787bfbea1d5783ba781e01b2f4160c
#   Stored in directory: /root/.cache/pip/wheels/df/e8/50/8d6a7119bc8829b70c66573d84e09873d611f9244cf5a1d1b2
# Successfully built investpy
# Installing collected packages: Unidecode, investpy
# Successfully installed Unidecode-1.4.0 investpy-1.0.8

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# !pip install datetime
# Out:
# Collecting datetime
#   Downloading DateTime-5.5-py3-none-any.whl.metadata (33 kB)
# Collecting zope.interface (from datetime)
#   Downloading zope.interface-7.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from datetime) (2025.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from zope.interface->datetime) (75.2.0)
# Downloading DateTime-5.5-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 kB 3.7 MB/s eta 0:00:00
# Downloading zope.interface-7.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (259 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.8/259.8 kB 11.5 MB/s eta 0:00:00
# Installing collected packages: zope.interface, datetime
# Successfully installed datetime-5.5 zope.interface-7.2

# %%
# !pip install fredapi
# Out:
# Collecting fredapi
#   Downloading fredapi-0.5.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from fredapi) (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas->fredapi) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->fredapi) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->fredapi) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->fredapi) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->fredapi) (1.17.0)
# Downloading fredapi-0.5.2-py3-none-any.whl (11 kB)
# Installing collected packages: fredapi
# Successfully installed fredapi-0.5.2

# %% [markdown]
# ##Implementação dos pacotes

# %% [markdown]
# Importação dos pacotes utilizados no código.

# %%
import time
import requests
import pandas as pd
import yfinance as yf

from bcb import sgs
from fredapi import Fred
from datetime import datetime
from IPython.display import clear_output
from concurrent.futures import ThreadPoolExecutor, as_completed

# %% [markdown]
# # Dados

# %% [markdown]
# * Seção onde todas as listas de dicionários disponíveis para busca no "Principal" podem ser encontradas.
#
# * Todos os dicionários possuem uma chave "nome", que armazena o nome do dado ou do subgrupo.
#
# * A estrutura dos dicionários varia:
#
#   * Alguns contêm uma chave "lista", que é uma lista de dicionários (separação por subgrupos para melhor visualização).
#
#   * Outros têm as chaves "código" ou "ticker", utilizadas para identificar o dado em pacotes de web scraping.
#
# * De modo geral:
#
#   * Dicionários com "ticker" vêm do pacote yfinance.
#
#   * Dicionários com "código" vêm de dados macroeconômicos (pacotes python-bcb ou fredapi).
#
# * Essas opções podem ser visualizadas de forma mais detalhada nas seções **Dados** e **Glossário**.

# %% [markdown]
# ##[0] Indicadores Macroeconômicos Brasileiros

# %% [markdown]
# Dados econômicos fornecidos pelo Banco Central do Brasil.

# %%
#0) Indicadores de Política Monetária e Inflação
selicMeta = {"nome": "Tx SELIC - Meta",
              "codigo": 11}
selicOver = {"nome": "Tx SELIC - Over",
              "codigo": 1178}
ipca = {"nome": "IPCA – Índice Nacional de Preços ao Consumidor Amplo",
              "codigo": 433}
igpM = {"nome": "IGP-M – Índice Geral de Preços (Mercado)",
              "codigo": 189}
tr = {"nome": "TR - Tx Referecial",
              "codigo": 226}

ipmi = {"nome":"Indicadores de Política Monetária e Inflação",
        "lista": [selicMeta,selicOver,ipca,igpM,tr]}


#1) Mercado de Créditos
credSisFinNAC = {"nome":"Crédito Total do Sistema Financeiro Nacional",
                 "codigo": 2004}
txMedJurosOpCred = {"nome":"Tx Média de Juros das Operações de Crédito com Recursos Livres – PJ",
                 "codigo": 20724}
inadimpPF = {"nome":"Inadimplência – PF",
                 "codigo": 21082}
inadimpPJ = {"nome":"Inadimplência – PJ",
                 "codigo": 21083}

mc = {"nome":"Mercado de Créditos",
        "lista":[credSisFinNAC,txMedJurosOpCred,inadimpPF,inadimpPJ]}

#2) Setor Externo e Câmbio
txCamb = {"nome":"Tx de Câmbio – Comercial (venda)",
          "codigo": 1}
totReservaInt = {"nome": "Reservas Internacionais – Total",
                 "codigo": 3548}
balComEXP = {"nome":"Balança Comercial – Exportações",
          "codigo": 22598}
balComIMP = {"nome":"Balança Comercial – Importações",
          "codigo": 22599}

sec = {"nome":"Setor Externo e Câmbio",
        "lista":[txCamb,totReservaInt,balComEXP,balComIMP]}

#3) Finanças Públicas
resultPrimSPubCons = {"nome":"Resultado Primário do Setor Público Consolidado",
                      "codigo": 13762}
divBrGovG = {"nome":"Dívida Bruta do Governo Geral",
            "codigo": 4503}
divLiqSPub = {"nome":"Dívida Líquida do Setor Público",
            "codigo": 4502}

fp = {"nome":"Finanças Públicas",
        "lista":[resultPrimSPubCons,divBrGovG,divLiqSPub]}

#4) Indicadores de Atividade Econômica
ibcBr = {"nome":"IBC-Br – Índice de Atividade Econômica do BC",
         "codigo": 24363}
pib = {"nome":"PIB - Produto Interno Bruto",
         "codigo": 4380}
prodIndG = {"nome":"Produção Industrial – Geral",
         "codigo": 21859}
recServ = {"nome":"Receita de Serviços",
         "codigo": 22720}

iae = {"nome":"Indicadores de Atividade Econômica",
        "lista":[ibcBr,pib,prodIndG,recServ]}

#5) Expectativas de Mercado (Boletim Focus)
expecIPCA = {"nome":"Expectativa de IPCA – 12 meses à frente",
         "codigo": 4390}
expecSelic = {"nome":"Expectativa de Selic – 12 meses à frente",
         "codigo": 1178}
expecCamb = {"nome":"Expectativa de Câmbio – 12 meses à frente",
         "codigo": 10813}

expecM = {"nome":"Expectativas de Mercado (Boletim Focus)",
        "lista":[expecIPCA,expecSelic,expecCamb]}

# %% [markdown]
# ##[1] Indicadores Macroeconômicos EUA

# %% [markdown]
# Dados do FRED (Federal Reserve Economic Data) dos Estados Unidos.

# %%
#0) Indicadores de Crescimento Econômico
pibRealUS = {"nome": "PIB real (anualizado, trimestral)",
             "codigo": "GDPC1"}
pibNomUS = {"nome": "PIB nominal (trimestral)",
             "codigo": "GDP"}
consFamUS = {"nome": "Consumo das Famílias",
             "codigo": "PCEC"}
invPrivBrUS = {"nome": "Investimento Privado Bruto",
             "codigo": "GPDIC1"}
prodIndUS = {"nome": "Produção Industrial",
             "codigo": "INDPRO"}

icreUS = {"nome": "Indicadores de Crescimento Econômico",
             "lista": [pibRealUS,pibNomUS,consFamUS,invPrivBrUS,prodIndUS]}

#1) Indicadores de Inflação
cpiGeUS = {"nome": "Índice de Preços ao Consumidor (CPI) - Geral",
             "codigo": "CPIAUCSL"}
cpiCoUS = {"nome": "Core CPI (exclui alimentos e energia)",
             "codigo": "CPILFESL"}
pceGeUS = {"nome": "Índice de Preços (PCE) - Despesas de Consumo Pessoal",
             "codigo": "PCE"}
pceCoUS = {"nome": "Core PCE",
             "codigo": "PCEPILFE"}

ifUS = {"nome": "Indicadores de Inflação",
             "lista": [cpiGeUS,cpiCoUS,pceGeUS,pceCoUS]}

#2) Indicadores de Mercado de Trabalho
u3US = {"nome": "Taxa de Desemprego (U-3)",
             "codigo": "UNRATE"}
pftUS = {"nome": "Participação da Força de Trabalho",
             "codigo": "CIVPART"}
cvsnaUS = {"nome": "Criação de Vagas no Setor Não-Agrícola",
             "codigo": "PAYEMS"}
aheUS = {"nome": "Índice de Salários (Average Hourly Earnings)",
             "codigo": "CES0500000003"}

imtUS = {"nome": "Indicadores de Mercado de Trabalho",
             "lista": [u3US,pftUS,cvsnaUS,aheUS]}

#3) Indicadores de Política Monetária e Taxas
fedUS = {"nome": "Federal Funds Rate (Tx Básica do Fed)",
             "codigo": "FEDFUNDS"}
tre10US = {"nome": "Tx de Juros dos Treasuries (10 anos)",
             "codigo": "GS10"}
spreadUS = {"nome": "Curva de Juros 10Y-2Y (spread)",
             "codigo": "T10Y2Y"}
txInfImp5US = {"nome": "Tx de Inflação Implícita (5 anos)",
             "codigo": "T5YIE"}

ipmtUS = {"nome": "Indicadores de Política Monetária e Taxas",
             "lista": [fedUS,tre10US,spreadUS,spreadUS,txInfImp5US]}

#4) Indicadores de Confiança e Expectativas
indConfConUS = {"nome": "Índice de Confiança do Consumidor (Conference Board)",
             "codigo": "CONCCONF"}
indSentConUS = {"nome": "Índice de Sentimento do Consumidor (University of Michigan)",
             "codigo": "UMCSENT"}
busConfIdxUS = {"nome": "Business Confidence Index (OECD - EUA)",
             "codigo": "BCIUSA"}
leEcIdx = {"nome": "Leading Economic Index (LEI)",
             "codigo": "USSLIND"}

icoeUS = {"nome": "Indicadores de Confiança e Expectativas",
             "lista": [indConfConUS,indSentConUS,busConfIdxUS,leEcIdx]}

#5) Indicadores Fiscais e de Crédito
divFedBrUS = {"nome": "Dívida federal bruta",
             "codigo": "GFDEBTN"}
defPubFedUS = {"nome": "Déficit público federal",
             "codigo": "MTSDS133FMS"}
totEmpBanComUS = {"nome": "Total de empréstimos bancários Comerciais",
             "codigo": "TOTBKCR"}

ifdUS = {"nome": "Indicadores Fiscais e de Crédito",
             "lista": [divFedBrUS,defPubFedUS,totEmpBanComUS]}

# %% [markdown]
# ##[2] Commodities

# %% [markdown]
# Preços e índices de commodities como petróleo, ouro, etc.

# %%
#0) Energia
petrBrent = {"nome":"Petróleo Brent (Global)",
             "ticker":"BZ=F"}
petrWTI = {"nome":"Petróleo WTI (EUA)",
             "ticker":"CL=F"}
gasNat = {"nome":"Gás Natural",
             "ticker":"NG=F"}
gasolRef = {"nome":"Gasolina RBOB",
             "ticker":"RB=F"}
olAquec = {"nome":"Óleo de Aquecimento",
             "ticker":"HO=F"}
prop = {"nome":"Propano",
             "ticker":"PN=F"}
etanol = {"nome":"Etanol",
             "ticker":"AC=F"}
carv = {"nome":"Carvão",
             "ticker":"	QL=F"}

energ = {"nome":"Energia",
            "lista":[petrBrent,petrWTI,gasNat,gasolRef,olAquec,prop,etanol,carv]}

#1) Metais Preciosos
au = {"nome":"Ouro",
             "ticker":"GC=F"}
ag = {"nome":"Prata",
             "ticker":"SI=F"}
pt = {"nome":"Platina",
             "ticker":"	PL=F"}
pd = {"nome":"Paládio",
             "ticker":"	PA=F"}

mp = {"nome":"Metais Preciosos",
        "lista":[au,ag,pt,pd]}

#2) Metais Industriais
cu = {"nome":"Cobre",
             "ticker":"HG=F"}
al = {"nome":"Alumínio",
             "ticker":"AL=F"}
zn = {"nome":"Zinco",
             "ticker":"	ZN=F"}
ni = {"nome":"Níquel",
             "ticker":"	NI=F"}

mi = {"nome":"Metais Industriais",
        "lista":[cu,al,zn,ni]}

#3) Grãos e Fibras
mil = {"nome":"Milho",
             "ticker":"ZC=F"}
sojGr = {"nome":"Soja em grão",
             "ticker":"ZS=F"}
tri = {"nome":"Trigo",
             "ticker":"	ZW=F"}
sojFar = {"nome":"Farelo de Soja",
             "ticker":"ZM=F"}
sojOl = {"nome":"óleo de Soja",
             "ticker":"ZL=F"}
arr = {"nome":"Arroz",
             "ticker":"	ZR=F"}
ave = {"nome":"Aveia",
             "ticker":"ZO=F"}

gf = {"nome":"Grãos e Fibras",
        "lista":[mil,sojGr,tri,sojFar,sojOl,arr,ave]}

#4) Soft Commodities
cafeArab = {"nome":"Café Arábica",
             "ticker":"KC=F"}
sugarBr = {"nome":"Açúcar Bruto (No.11)",
             "ticker":"SB=F"}
cac = {"nome":"Cacau",
             "ticker":"	CC=F"}
algod = {"nome":"Algodão (Fibra têxtil)",
             "ticker":"CT=F"}
sucoLarConc = {"nome":"Suco de Laranja Concentrado",
             "ticker":"OJ=F"}

sc = {"nome":"Soft Commodities",
        "lista":[cafeArab,sugarBr,cac,algod,sucoLarConc]}

#5) Pecuária
gaVivo = {"nome":"Gado Vivo",
             "ticker":"LE=F"}
gaEngo = {"nome":"Gado de Engorda",
             "ticker":"GF=F"}
suiMag = {"nome":"Suínos Magros",
             "ticker":"HE=F"}

pec = {"nome":"Pecuária",
        "lista":[gaVivo,gaEngo,suiMag]}

# %% [markdown]
# ##[3] Indices Globais

# %% [markdown]
# Informações sobre os principais índices de ações globais, como o S&P 500 e outros.

# %%
#0) Gerais
msciWI = {"nome":"MSCI World Index (ETF)",
          "ticker":"URTH"}
msciEM = {"nome":"MSCI Emerging Markets (ETF)",
          "ticker":"EEM"}
spGSCI = {"nome":"S&P GSCI Commodity Index Future",
             "ticker":"GD=F"}

indGe = {"nome":"Gerais",
        "lista":[msciWI,msciEM,spGSCI]}

#1) EUA
sp500 = {"nome":"S&P 500 (EUA)",
          "ticker":"^GSPC"}
indicVol = {"nome":"Índice de Volatilidade (S&P 500)",
          "ticker":"^VIX"}
rus2000 = {"nome":"Russell 2000 (EUA - small caps)",
          "ticker":"^RUT"}
NasdaqComp = {"nome":"Nasdaq Composite (EUA - tecnologia)",
          "ticker":"^IXIC"}

indUS = {"nome":"Estados Unidos",
        "lista":[sp500,indicVol,rus2000,NasdaqComp]}

#2) Américas
ipcMex = {"nome":"IPC México",
          "ticker":"^MXX"}
tsxComp = {"nome":"S&P/TSX Composite",
          "ticker":"^GSPTSE"}
ibov = {"nome":"Ibovespa (Bra)",
          "ticker":"^BVSP"}
merv = {"nome":"MERVAL (Arg)",
          "ticker":"^MERV"}

indAm = {"nome":"Américas",
        "lista":[ipcMex,tsxComp,ibov,merv]}

#3) Europa
eustox50 = {"nome":"Euro Stoxx 50",
          "ticker":"^STOXX50E"}
ftse100 = {"nome":"FTSE 100 (UK)",
          "ticker":"^FTSE"}
dax = {"nome":"DAX (Ale)",
          "ticker":"^GDAXI"}
cac40 = {"nome":"CAC 40 (Fra)",
          "ticker":"^FCHI"}

indEu = {"nome":"Europa",
        "lista":[eustox50,ftse100,dax,cac40]}

#4) Ásia & Oceania
nik225 = {"nome":"Nikkei 225 (Jap)",
          "ticker":"^N225"}
shangComp = {"nome":"Shanghai Composite (Chi)",
          "ticker":"000001.SS"}
kospi = {"nome":"KOSPI (Kor)",
          "ticker":"^KS11"}
bseSen = {"nome":"BSE SENSEX (Ind)",
          "ticker":"^BSESN"}
asx200 = {"nome":"S&P/ASX 200 (Aus)",
          "ticker":"^AXJO"}

indAO = {"nome":"Ásia & Oceania",
        "lista":[nik225,shangComp,kospi,bseSen,asx200]}

# %% [markdown]
# ##[4] Ações da B3

# %% [markdown]
# * O pacote **yfinance** não disponibiliza uma lista completa de ações de uma bolsa, exigindo que o usuário conheça o ticker.
#
# * Para contornar isso:
#
#   * A função **obterTicker()** faz web scraping da API gratuita brapi.dev para obter os tickers atualizados da B3.
#
#   * A função **filtraAções()** separa os tickers em três subgrupos:
#
#     * Ações brasileiras (4 letras terminadas em "3" ou "4").
#
#     * BDRs (terminadas entre "31" e "39").
#
#     * Fundos/ETFs (terminadas em "11").
#
#   * Um filtro adicional foi aplicado para evitar sobrecarga de dados (principalmente nas ações brasileiras).
#
#   * A função **obter_info_ticker()** usa **concurrent.futures** para otimizar o processo de consulta dos nomes das ações no **yfinance**, reduzindo o tempo de execução.

# %%
def obterTicker():
    # Primeiro obtemos a lista de tickers disponíveis
    url_available = "https://brapi.dev/api/available"

    try:
        response = requests.get(url_available)

        if response.status_code != 200:
            print(f"Erro ao acessar a API. Código: {response.status_code}")
            return []

        data = response.json()

        # Obter todos os tickers, não apenas os com comprimento >= 5
        tickers = data.get('stocks', [])

        return tickers

    except Exception as e:
        print(f"Erro ao acessar a API: {e}")
        return []

def filtraAcoes(dadosB3):
    acoesBR = []
    acoesBDR = []
    acoes11 = []

    # Dicionários para verificação rápida (em vez de loops aninhados)
    acoesBR_set = set()
    acoesBDR_set = set()
    acoes11_set = set()

    # Definir os padrões
    tickerFBR = ["3", "4"]
    tickerBDR = ["31","32","33","34","35","36","37","38","39"]
    ticker11 = "11"

    for ticker in dadosB3:
        # Verificando ações que terminam com '3' ou '4'
        if ticker[-1] in tickerFBR and ticker[-2].isalpha():
            prefixo_ticker = ticker[0:4]

            if prefixo_ticker not in acoesBR_set:
                acoesBR.append({"nome": ticker, "ticker": f"{ticker}.SA"})
                acoesBR_set.add(prefixo_ticker)

        # Verificando BDRs
        elif ticker[-2:] in tickerBDR:
            if ticker not in acoesBDR_set:
                acoesBDR.append({"nome": ticker, "ticker": f"{ticker}.SA"})
                acoesBDR_set.add(ticker)

        # Verificando ticker11
        elif ticker[-2:] == ticker11:
            if ticker not in acoes11_set:
                acoes11.append({"nome": ticker, "ticker": f"{ticker}.SA"})
                acoes11_set.add(ticker)

    return acoesBR, acoesBDR, acoes11

def obter_info_ticker(item):
    try:
        info = yf.Ticker(item["ticker"]).info
        nome = info.get('longName') or info.get('shortName')
        if nome:
            return {"nome": f"{nome} ({item['nome']})", "ticker": item["ticker"]}
        return None
    except Exception as e:
        return None

def pegaNomeAcao(lista, max_workers=10):
    acoes = []

    # Usar ThreadPoolExecutor para paralelizar as requisições
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Processar em paralelo e coletar os resultados
        resultados = list(executor.map(obter_info_ticker, lista))

    # Filtrar os resultados None (erros) e ordenar
    acoes = [r for r in resultados if r is not None]
    acoes = sorted(acoes, key=lambda x: x["nome"])

    return acoes

# %%
acoesB3 = obterTicker()

aebL = []
bdrL = []
a11L = []

aebL, bdrL, a11L = filtraAcoes(acoesB3)

#0) Ações de Empresas Brasileiras
listaABR = pegaNomeAcao(aebL, max_workers=10)
aeb = {"nome": "Ações de Empresas Brasileiras",
       "lista": listaABR}

#1) Brazilian Depositary Receipt (BDR)
listaABDR = pegaNomeAcao(bdrL, max_workers=10)
bdr = {"nome": "Brazilian Depositary Receipt (BDR)",
         "lista":listaABDR}

#2) Fundos de Investimento e ETF
listaA11 = pegaNomeAcao(a11L, max_workers=10)
fie = {"nome": "Fundos de Investimento e ETF",
         "lista":listaA11}

# %% [markdown]
# ##[5] Análise Financeira das empresas

# %% [markdown]
# * Para análise de empresas estrangeiras via BDRs:
#
#   * As informações financeiras relevantes estão disponíveis na bolsa de origem da empresa (geralmente a Bolsa de Nova Iorque).
#
#   * A função **selecionaEmpGr()** adapta os tickers dos BDRs para a forma correta de consulta.

# %%
def selecionaEmpGr(listaBDR):
    listaEst = []
    chv = ["nome", "ticker"]

    for i in listaBDR:
        listaEst.append(dict(zip(chv, [i['nome'], i['ticker'][0:4]])))

    return listaEst

# %%
#0) Empresas brasileiras
empBR = {"nome": "Empresas Brasileiras (listadas na B3)",
         "lista": listaABR}

#1) Empresas gringas com BDR
listaEmpEs = selecionaEmpGr(listaABDR)
empGr = {"nome": "Empresas Estrangeiras (possuem BDRs)",
         "lista": listaEmpEs}

# %% [markdown]
# ##[6]Principais Criptmoedas

# %% [markdown]
# * Assim como nas ações, o **yfinance** não fornece uma lista completa das criptomoedas.
#
# * Utiliza-se a API gratuita da CoinGecko para listar as 100 criptomoedas mais valorizadas.
#
# * A função **top20criptomoedas()** seleciona, dentre essas 100, as 20 disponíveis no yfinance utilizando multitarefa com **concurrent.futures**.
#
# * Algumas adaptações no código foram feitas para lidar com a ausência de subdivisões no grupo de criptomoedas.

# %%
def verificar_ticker(candidato):
    """
    Função auxiliar para verificar se um ticker está disponível no yfinance
    """
    try:
        ticker_info = yf.Ticker(candidato["ticker"])
        info = ticker_info.info

        # Se chegou aqui, o ticker existe no yfinance
        if 'regularMarketPrice' in info or 'currentPrice' in info:
            candidato["nome"] = f"{candidato['nome']} ({candidato['ticker']})"
            return candidato
        return None
    except:
        return None

def top20criptomoedas(max_workers=10):
    """
    Obtém as 20 principais criptomoedas disponíveis no yfinance
    usando processamento paralelo

    Args:
        max_workers: Número máximo de threads para processamento paralelo

    Returns:
        Lista das criptomoedas encontradas
    """
    try:
        # Obter lista das principais criptomoedas via API
        url = "https://api.coingecko.com/api/v3/coins/markets"
        params = {
            "vs_currency": "usd",
            "order": "market_cap_desc",
            "per_page": 100,  # Pegamos 100 para ter margem caso algumas não estejam no yfinance
            "page": 1
        }


        response = requests.get(url, params=params)

        if response.status_code != 200:
            return []

        data = response.json()

        # Criar lista de candidatos a tickers para o yfinance
        candidatos = []
        for coin in data:
            symbol = coin['symbol'].upper()
            ticker = f"{symbol}-USD"
            nome = coin['name']
            candidatos.append({"nome": nome, "ticker": ticker})

        resultado = []

        with ThreadPoolExecutor(max_workers=max_workers) as executor:
            # Mapear a função de verificação para todos os candidatos
            futures = list(executor.map(verificar_ticker, candidatos))

            # Filtrar resultados válidos (não-None)
            resultado = [r for r in futures if r is not None]

        return resultado[:20]

    except Exception as e:
        return []

# %% [markdown]
# ##Busca do período

# %% [markdown]
# Alguns dados são melhores de ser procurados em um método específico, invés de disponibilizar pelos 2 métodos. Esses dicionários separam esses tipos de dados para selecionar a função de escolha de período.

# %%
nseries = {"tipo":1,
           "lista": [pib]}

dataseries = {"tipo":2,
              "lista": [selicMeta,expecIPCA,expecSelic,expecCamb,txCamb,listaABR,listaABDR,listaA11,
                        msciWI,msciEM,spGSCI,sp500,indicVol,rus2000,NasdaqComp,ipcMex,tsxComp,ibov,merv,
                        eustox50,ftse100,dax,cac40,nik225,shangComp,kospi,bseSen,asx200,petrBrent,
                        petrWTI,gasNat,gasolRef,olAquec,prop,etanol,carv,au,ag,pt,pd,cu,al,zn,ni,
                        mil,sojGr,tri,sojFar,sojOl,arr,ave,cafeArab,sugarBr,cac,algod,sucoLarConc,
                        gaVivo,gaEngo,suiMag]}

# %% [markdown]
# ##Grupo de dados

# %%
#[0] Indicadores Macroeconômicos Brasileiros
grpMacroBR = {"nome":"Indicadores Macroeconômicos Brasil",
            "lista":[ipmi,mc,sec,fp,iae,expecM]}

#[1] Indicadores Macroeconômicos EUA
grpMacroUS = {"nome":"Indicadores Macroeconômicos EUA",
              "lista": [icreUS,ifUS,imtUS,ipmtUS,icoeUS,ifdUS]}

#[2] Commodities
grpCom = {"nome":"Commodities",
        "lista":[energ,mp,mi,gf,sc,pec]}

#[3] Indices Globais
grpIG = {"nome":"Indices Globais da Bolsa de Valores",
        "lista":[indGe,indUS,indAm,indEu,indAO]}

#[4] Ações da B3
grpB3 = {"nome": "Acoes da B3",
         "lista": [aeb,bdr,fie]}

#[5] Análise de Empresas
grpFin = {"nome": "Análise Financeira das empresas",
          "lista": [empBR,empGr]}

#[6] Criptomoedas
grpCrip = {"nome": "Criptomoedas",
           "lista": top20criptomoedas(max_workers=10)}

#Areas de pesquisa
grp = [grpMacroBR,grpMacroUS,grpCom,grpIG,grpB3,grpFin,grpCrip]

# %% [markdown]
# # Funções Gerais

# %% [markdown]
# * As **Funções Gerais** são responsáveis por fornecer a funcionalidade básica e central do programa. Elas são projetadas para facilitar a interação com os dados e otimizar a execução das tarefas.
#
# * São também funções fundamentais para que o usuário consiga explorar os dados disponíveis, realizar consultas de forma eficiente e salvar os resultados para futuras análises.

# %% [markdown]
# ##funções de de tempo

# %% [markdown]
# * A função **escolhePeriodo()** permite ao usuário definir o recorte temporal:
#
#   * Pela quantidade de séries mais recentes.
#
#   * Ou pela seleção de data inicial e final.
#
#   * Algumas fontes de dados só aceitam uma dessas opções.
#
# * A **função confereData()** auxilia na validação de datas digitadas, minimizando erros de entrada.
#
# * A **função confereG2per()** verifica o tipo de dado que está sendo analisado para dispnibilizar as melhores formas de fazer um recorte temporal dele, usando os dicionários **nseries** e **dataseries** como referência, para diminuir a chance de gerar um DataFrame vazio no fim da execussão do programa.

# %%
def confereData(data):
    if data[0:2].isnumeric():
      dia = int(data[0:2])
    else:
      return False
    if data[3:5].isnumeric():
      mes = int(data[3:5])
    else:
      return False
    if data[6:10].isnumeric():
      ano = int(data[6:10])
    else:
      return False
    divData = [data[2],data[5]]

    dataAGR = datetime.now()

    m31 = [1,3,5,7,8,9,12]
    m28 = 2
    m30 = [4,6,9,11]
    divPos = ["-","/"]

    if divData[0] not in divPos or divData[1] not in divPos:
        return False
    if ano > dataAGR.year:
        return False
    elif dia == 31:
        if ano not in m31:
            return False
    elif dia > 31:
        return False
    elif mes > 12:
        return False
    elif mes == m28 and dia > 29:
        return False
    elif mes == m28 and dia == 29:
        if ano % 400 != 0:
            return False
        else:
            if ano % 100 == 0:
                return False
            else:
                if ano % 4 != 0:
                    return False
    return True

def escolhePeriodo(n):

    if n == 3:
        print("Como procurar a série temporal do dado:")
        print("[1] Últimas 'n' séries salvas")
        print("[2] De uma data até outra")
        tipoPer = int(input("Método Escolhido: "))
        print("-=" * 20)
    else:
        if n == 1:
          tipoPer = 1
        else:
          tipoPer = 2

    if tipoPer == 1:
        per = int(input("Quantas últimas 'n' series temporais: "))
        print("-=" * 20)
        return [tipoPer, per, "d"]

    elif tipoPer == 2:
        dataInic = input("Data inicial da série (DD-MM-AAAA): ")
        if confereData(dataInic) == False:
            while confereData(dataInic) == False:
                print("Você inseriu uma data incorreta! Insira uma data válida.")
                print("Se uma parte da data tiver apenas um dígito, coloque um zero antes.")
                dataInic = input("Data inicial da série (DD-MM-AAAA): ")

        print("-=" * 20)
        dataFin = input("Data final da série (DD-MM-AAAA): ")
        if confereData(dataFin) == False:
            while confereData(dataFin) == False:
                print("Você inseriu uma data incorreta! Insira uma data válida.")
                print("Se uma parte da data tiver apenas um dígito, coloque um zero antes.")
                dataFin = input("Data final da série (DD-MM-AAAA): ")

        print("-=" * 20)
        return [tipoPer, dataInic, dataFin]

def confereG2per(g2):
  ntp = 0
  for i in dataseries:
    if type(i) == list:
      if g2 in i:
        ntp = dataseries["tipo"]
    else:
      if g2 == i:
        ntp = dataseries["tipo"]

  if ntp == 0:
    if g2 == nseries["lista"]:
      ntp = nseries["tipo"]
    else:
      ntp = 3
  return ntp

# %% [markdown]
# ##Criar DataFrame

# %% [markdown]
# * Funções específicas para criar DataFrames a partir dos dados extraídos, ajustadas conforme a fonte (pacotes ou APIs).

# %%
def criaDF_bcb(g,cod, ntp):
    p = escolhePeriodo(ntp)

    if p[0] == 1:
        csv = sgs.get(cod,last=p[1])

    elif p[0] == 2:
        d1 = datetime.strptime(p[1], "%d-%m-%Y").date()
        d2 = datetime.strptime(p[2], "%d-%m-%Y").date()
        csv = sgs.get(cod, start=d1,end=d2)

    print(g["nome"])
    print(csv)
    print("-=" * 20)
    return csv

def criaDF_fred(dado):
  fred = Fred(api_key='ba12fc16c8976c6dc30568359c97fc79')
  csv = fred.get_series(dado)

  print(dado["nome"])
  print(csv)
  print("-=" * 20)
  return csv


def criaDF_yfinance(tick, ntp):

  per = escolhePeriodo(ntp)
  tipoP = per[0]

  emp = yf.Ticker(tick)  # Garantir que 'tick' seja um ticker válido
  if tipoP == 1:
      p,tp = per[1], per[2]
      csv = emp.history(period=f"{p}{tp}")
  elif tipoP == 2:
      d1,d2 = per[1], per[2]
      d1 = datetime.strptime(d1, "%d-%m-%Y").date()
      d2 = datetime.strptime(d2, "%d-%m-%Y").date()
      csv = emp.history(start=d1, end=d2)

  print(g2["nome"])
  print(csv)
  print("-=" * 20)
  return csv


def dadosFincDF(tick):
    while True:
      print("-="*20)
      print("[1] Fluxo de Caixa")
      print("[2] Balanço patrimonial")
      print("[3] Demonstração de resultado (DRE)")

      tipod = int(input("Qual tipo de Análise da empresa você quer fazer?"))
      if tipod in [1,2,3]:
        break
      else:
        print("-=" * 20)
        print("Opção invalida, digite um valor válido!")
        print("-=" * 20)

    if tipod == 1:
        emp = yf.Ticker(tick)
        csv = emp.financials
    elif tipod == 2:
        emp = yf.Ticker(tick)
        csv = emp.balance_sheet
    elif tipod == 3:
        emp = yf.Ticker(tick)
        csv = emp.cashflow

    print(g2["nome"])
    print(csv)
    print("-=" * 20)
    return(csv)

# %% [markdown]
# ##Criar CSV

# %%
def criaCSV(df):
  if not dadof.empty:
    nome_arquivo = g2["nome"].replace(" ", "_").replace("–", "-") + ".csv"
    dadof.to_csv(nome_arquivo, index=True, encoding='utf-8-sig')
    print(f"Dados salvos em: {nome_arquivo}")
  else:
    print("Nenhum dado para salvar.")
  print("-=" * 20)
  print("Execução do programa terminado.")
  return

# %% [markdown]
# ##Listar dados

# %% [markdown]
# * A função **listarDados()** lista todos os dados disponíveis.
#
# * A função **listarMuitosDados()** lista dados de n a m dentro de uma lista de dados.

# %%
def listarDados(dados):
    n = 0
    for i in dados:
        d = i["nome"]
        print(f"[{n}] {d}")
        n += 1
    return

def listarMuitosDados(dados, inic, fin):
    # Ajustando para garantir que o índice fin não ultrapasse o tamanho da lista
    fin = min(fin, len(dados) - 1)  # Garantir que 'fin' não seja maior que o último índice

    n = inic
    print("~x"*20)
    print(f"Itens [{inic}] - [{fin}]")
    print("~x"*20)
    for i in range(inic, fin + 1):
        if i < len(dados):  # Verifica se o índice 'i' está dentro dos limites da lista
            d = dados[i]["nome"]
            print(f"[{n}] {d}")
            n += 1
    return

# %% [markdown]
# ##Interface interativa

# %% [markdown]
# * As funções **pegaInfo0()**, **pegaInfo1()** e **pegaInfo2()** são usadas dentro da função principal **pegaInfo()**.
#
# * Elas guiam o usuário na seleção de:
#
#   * Grupo de dados.
#
#   * Subgrupo.
#
#   * Dado específico.
#
# * É possível retornar à seleção anterior digitando -1.

# %%
def confereInfo(gAnt, gAgr):
    # Verificar se gAgr é numérico ou se é o valor -1 para voltar
    if not gAgr.lstrip("-").isnumeric() and gAgr != "-1":
        return False
    else:
        # Verificar se gAgr está dentro do intervalo válido
        if int(gAgr) > len(gAnt) or int(gAgr) < -1:
            return False
        else:
            return True

def pegaInfo0():
    """
    Seleciona um grupo do primeiro nível
    """
    print("-="*20)
    print("Informação #1")

    resp = 0
    while resp == 0:
        print("-="*20)
        listarDados(grp)
        print("-="*20)
        entrada = input("Digite o número do grupo dos dados [-1 = sair]: ")
        print("-="*20)

        # Validação da entrada
        if not confereInfo(grp, entrada):
            print(f"Valor inválido! Digite um número entre 0 e {len(grp)-1} ou -1.")
            continue
        else:
          info0 = int(entrada)
          break

    if info0 == -1:
        return -1
    else:
        return grp[info0]

def pegaInfo1(g0):
    """
    Seleciona um item do segundo nível
    """
    print("Informação #2")
    print("-="*20)

    resp = 0
    while resp == 0:
        listarDados(g0["lista"])
        print("-="*20)
        if g0 == grp[6]:
          entrada = input("Digite número do dado para ser analisado [-1 = voltar]: ")
        else:
          entrada = input("Digite o número do subgrupo do dado [-1 = voltar]: ")
        print("-="*20)

        # Validação da entrada
        if not confereInfo(g0["lista"],entrada):
            print(f"Valor inválido! Digite um número entre 0 e {len(g0['lista'])-1} ou -1.")
            continue
        else:
          info1 = int(entrada)
          break

    if info1 == -1:
        return -1
    else:
        return g0["lista"][info1]

def pegaInfo2(g1):
    """
    Seleciona um item do terceiro nível
    """
    print("Informação #3")
    print("-="*20)

    # Caso especial para criptomoedas
    if g1 in grpCrip["lista"]:
        return g1

    # Todos os outros casos
    casos = [grpB3["lista"][0], grpB3["lista"][1], grpB3["lista"][2],
             grpFin["lista"][0], grpFin["lista"][1]]

    # Verifica se o item está nos casos especiais (listas grandes)
    if g1 in casos:
        # Inicializa a paginação
        pagina_atual = 0
        itens_por_pagina = 75

        while True:
            inicio = pagina_atual * itens_por_pagina
            fim = inicio + itens_por_pagina - 1

            # Mostrar itens da página atual
            if inicio < len(g1["lista"]):
                listarMuitosDados(g1["lista"], inicio, min(fim, len(g1["lista"]) - 1))
                print("-="*20)

                # Opções de navegação
                opcoes = []
                if pagina_atual > 0:
                    print("[V] Voltar para página anterior")
                    opcoes.append("V")

                if fim < len(g1["lista"]) - 1:
                    print("[P] Para ir para a próxima página")
                    opcoes.append("P")

                entrada = input("Digite número do dado para ser analisado [-1 = voltar]: ")
                print("-="*20)

                # Processar entrada
                if entrada.upper() == "P" and "P" in opcoes:
                    pagina_atual += 1
                    continue
                elif entrada.upper() == "V" and "V" in opcoes:
                    pagina_atual -= 1
                    continue
                elif confereInfo(g1["lista"],entrada):
                    info2 = int(entrada)
                    if info2 == -1:
                        return -1
                    elif 0 <= info2 < len(g1["lista"]):
                        return g1["lista"][info2]
                else:
                    print(f"Valor inválido! Digite um número entre 0 e {len(g1['lista'])-1} ou -1.")

    else:
        # Para listas pequenas, mostrar tudo de uma vez
       while True:
          listarDados(g1["lista"])
          print("-="*20)
          entrada = input("Digite número do dado para ser analisado [-1 = voltar]: ")
          print("-="*20)

          # Validação da entrada
          if not confereInfo(g1["lista"],entrada):
            print(f"Valor inválido! Digite um número entre 0 e {len(g1['lista'])-1} ou -1.")
            continue
          else:
            info2 = int(entrada)
            break

          if info2 == -1:
            return -1
          else:
            return g1["lista"][info2]

def pegaInfo():
    grupos = [pegaInfo0, pegaInfo1, pegaInfo2]  # Lista de funções para os grupos
    grupo_atual = 0  # Começa no primeiro grupo
    resp = []  # Lista para armazenar as respostas

    while True:
        # Chama a função do grupo atual, passando a resposta anterior, se houver
        if grupo_atual == 0:
            resposta = grupos[grupo_atual]()  # Para o primeiro grupo
        elif grupo_atual == 1:
            resposta = grupos[grupo_atual](resp[0])  # Para o segundo grupo
        elif grupo_atual == 2:
            resposta = grupos[grupo_atual](resp[1])  # Para o terceiro grupo
        else:
            break  # Se o grupo não existir, sai do loop

        if resposta == -1:  # Caso o comando seja voltar ou sair
            if grupo_atual > 0:
                grupo_atual -= 1  # Volta para o grupo anterior
                resp.pop()  # Remove a última resposta da pilha
                print("Voltando para o grupo anterior...")
            else:
                print("Você já está no primeiro grupo.")
                break  # Se estiver no primeiro grupo, termina o loop
        else:
            grupo_atual += 1  # Atualiza para o próximo grupo
            resp.append(resposta)  # Adiciona a resposta à pilha

    return resp

# %% [markdown]
# #Glossário

# %% [markdown]
# Lista de opções disponíveis para escolha no terminal, correspondentes às seções "Principal" e "Dados".

# %% [markdown]
# ##[0], [1], [2] e [3]

# %%
# Todas as opções de subgrupos, menos na parte de ações da B3, análise de empresas e Criptomoedas
pular = [grpB3, grpFin, grpCrip]
n0 = 0  # Inicializa o contador antes do loop

for i in grp:
    if i not in pular:
        print(f"[{n0}] - {i['nome']}")

        # Verifica se i tem a chave 'lista' antes de tentar iterar
        if 'lista' in i:
            for n1, t in enumerate(i['lista']):
                print(f"[{n0}][{n1}] - {t['nome']}")

                # Verifica se t tem a chave 'lista' antes de tentar iterar
                if 'lista' in t:
                    for n2, s in enumerate(t['lista']):
                        print(f"[{n0}][{n1}][{n2}] - {s['nome']}")

        print("-="*20)

    n0 += 1
# Out:
# [0] - Indicadores Macroeconômicos Brasil
# [0][0] - Indicadores de Política Monetária e Inflação
# [0][0][0] - Tx SELIC - Meta
# [0][0][1] - Tx SELIC - Over
# [0][0][2] - IPCA – Índice Nacional de Preços ao Consumidor Amplo
# [0][0][3] - IGP-M – Índice Geral de Preços (Mercado)
# [0][0][4] - TR - Tx Referecial
# [0][1] - Mercado de Créditos
# [0][1][0] - Crédito Total do Sistema Financeiro Nacional
# [0][1][1] - Tx Média de Juros das Operações de Crédito com Recursos Livres – PJ
# [0][1][2] - Inadimplência – PF
# [0][1][3] - Inadimplência – PJ
# [0][2] - Setor Externo e Câmbio
# [0][2][0] - Tx de Câmbio – Comercial (venda)
# [0][2][1] - Reservas Internacionais – Total
# [0][2][2] - Balança Comercial – Exportações
# [0][2][3] - Balança Comercial – Importações
# [0][3] - Finanças Públicas
# [0][3][0] - Resultado Primário do Setor Público Consolidado
# [0][3][1] - Dívida Bruta do Governo Geral
# [0][3][2] - Dívida Líquida do Setor Público
# [0][4] - Indicadores de Atividade Econômica
# [0][4][0] - IBC-Br – Índice de Atividade Econômica do BC
# [0][4][1] - PIB - Produto Interno Bruto
# [0][4][2] - Produção Industrial – Geral
# [0][4][3] - Receita de Serviços
# [0][5] - Expectativas de Mercado (Boletim Focus)
# [0][5][0] - Expectativa de IPCA – 12 meses à frente
# [0][5][1] - Expectativa de Selic – 12 meses à frente
# [0][5][2] - Expectativa de Câmbio – 12 meses à frente
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# [1] - Indicadores Macroeconômicos EUA
# [1][0] - Indicadores de Crescimento Econômico
# [1][0][0] - PIB real (anualizado, trimestral)
# [1][0][1] - PIB nominal (trimestral)
# [1][0][2] - Consumo das Famílias
# [1][0][3] - Investimento Privado Bruto
# [1][0][4] - Produção Industrial
# [1][1] - Indicadores de Inflação
# [1][1][0] - Índice de Preços ao Consumidor (CPI) - Geral
# [1][1][1] - Core CPI (exclui alimentos e energia)
# [1][1][2] - Índice de Preços (PCE) - Despesas de Consumo Pessoal
# [1][1][3] - Core PCE
# [1][2] - Indicadores de Mercado de Trabalho
# [1][2][0] - Taxa de Desemprego (U-3)
# [1][2][1] - Participação da Força de Trabalho
# [1][2][2] - Criação de Vagas no Setor Não-Agrícola
# [1][2][3] - Índice de Salários (Average Hourly Earnings)
# [1][3] - Indicadores de Política Monetária e Taxas
# [1][3][0] - Federal Funds Rate (Tx Básica do Fed)
# [1][3][1] - Tx de Juros dos Treasuries (10 anos)
# [1][3][2] - Curva de Juros 10Y-2Y (spread)
# [1][3][3] - Curva de Juros 10Y-2Y (spread)
# [1][3][4] - Tx de Inflação Implícita (5 anos)
# [1][4] - Indicadores de Confiança e Expectativas
# [1][4][0] - Índice de Confiança do Consumidor (Conference Board)
# [1][4][1] - Índice de Sentimento do Consumidor (University of Michigan)
# [1][4][2] - Business Confidence Index (OECD - EUA)
# [1][4][3] - Leading Economic Index (LEI)
# [1][5] - Indicadores Fiscais e de Crédito
# [1][5][0] - Dívida federal bruta
# [1][5][1] - Déficit público federal
# [1][5][2] - Total de empréstimos bancários Comerciais
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# [2] - Commodities
# [2][0] - Energia
# [2][0][0] - Petróleo Brent (Global)
# [2][0][1] - Petróleo WTI (EUA)
# [2][0][2] - Gás Natural
# [2][0][3] - Gasolina RBOB
# [2][0][4] - Óleo de Aquecimento
# [2][0][5] - Propano
# [2][0][6] - Etanol
# [2][0][7] - Carvão
# [2][1] - Metais Preciosos
# [2][1][0] - Ouro
# [2][1][1] - Prata
# [2][1][2] - Platina
# [2][1][3] - Paládio
# [2][2] - Metais Industriais
# [2][2][0] - Cobre
# [2][2][1] - Alumínio
# [2][2][2] - Zinco
# [2][2][3] - Níquel
# [2][3] - Grãos e Fibras
# [2][3][0] - Milho
# [2][3][1] - Soja em grão
# [2][3][2] - Trigo
# [2][3][3] - Farelo de Soja
# [2][3][4] - óleo de Soja
# [2][3][5] - Arroz
# [2][3][6] - Aveia
# [2][4] - Soft Commodities
# [2][4][0] - Café Arábica
# [2][4][1] - Açúcar Bruto (No.11)
# [2][4][2] - Cacau
# [2][4][3] - Algodão (Fibra têxtil)
# [2][4][4] - Suco de Laranja Concentrado
# [2][5] - Pecuária
# [2][5][0] - Gado Vivo
# [2][5][1] - Gado de Engorda
# [2][5][2] - Suínos Magros
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# [3] - Indices Globais da Bolsa de Valores
# [3][0] - Gerais
# [3][0][0] - MSCI World Index (ETF)
# [3][0][1] - MSCI Emerging Markets (ETF)
# [3][0][2] - S&P GSCI Commodity Index Future
# [3][1] - Estados Unidos
# [3][1][0] - S&P 500 (EUA)
# [3][1][1] - Índice de Volatilidade (S&P 500)
# [3][1][2] - Russell 2000 (EUA - small caps)
# [3][1][3] - Nasdaq Composite (EUA - tecnologia)
# [3][2] - Américas
# [3][2][0] - IPC México
# [3][2][1] - S&P/TSX Composite
# [3][2][2] - Ibovespa (Bra)
# [3][2][3] - MERVAL (Arg)
# [3][3] - Europa
# [3][3][0] - Euro Stoxx 50
# [3][3][1] - FTSE 100 (UK)
# [3][3][2] - DAX (Ale)
# [3][3][3] - CAC 40 (Fra)
# [3][4] - Ásia & Oceania
# [3][4][0] - Nikkei 225 (Jap)
# [3][4][1] - Shanghai Composite (Chi)
# [3][4][2] - KOSPI (Kor)
# [3][4][3] - BSE SENSEX (Ind)
# [3][4][4] - S&P/ASX 200 (Aus)
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=

# %% [markdown]
# ##[4]

# %%
n0 = 4

print("-="*20)
print(f"[{n0}] - {grpB3['nome']}")
print("-="*20)

# Verifica se grpB3 tem a chave 'lista'
if 'lista' in grpB3:
    for n1, t in enumerate(grpB3['lista']):
        print(f"[{n0}][{n1}] - {t['nome']}")

        # Verifica se t tem a chave 'lista' antes de tentar iterar
        if 'lista' in t:
            for n2, s in enumerate(t['lista']):
                print(f"[{n0}][{n1}][{n2}] - {s['nome']}")

        print("-="*20)
# Out:
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# [4] - Acoes da B3
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# [4][0] - Ações de Empresas Brasileiras
# [4][0][0] - ATMA Participações S.A. (ATMP3)
# [4][0][1] - ATOM EDUC   ON (ATED3)
# [4][0][2] - AUTOMOB     ON      NM (AMOB3)
# [4][0][3] - Aeris Indústria e Comércio de Equipamentos para Geração de Energia S.A. (AERI3)
# [4][0][4] - AgroGalaxy Participações S.A. (AGXY3)
# [4][0][5] - Alfa Holdings S.A. (RPAD3)
# [4][0][6] - Alliança Saúde e Participações S.A. (AALR3)
# [4][0][7] - Allied Tecnologia S.A. (ALLD3)
# [4][0][8] - Allos S.A. (ALOS3)
# [4][0][9] - Allpark Empreendimentos, Participações e Serviços S.A. (ALPK3)
# [4][0][10] - Alpargatas S.A. (ALPA4)
# [4][0][11] - Alphaville S.A. (AVLL3)
# [4][0][12] - Alupar Investimento S.A. (ALUP4)
# [4][0][13] - Ambev S.A. (ABEV3)
# [4][0][14] - Ambipar Participações e Empreendimentos S.A. (AMBP3)
# [4][0][15] - Americanas S.A. (AMER3)
# [4][0][16] - Armac Locação, Logística e Serviços S.A. (ARML3)
# [4][0][17] - Atacadão S.A. (CRFB3)
# [4][0][18] - Auren Energia S.A. (AURE3)
# [4][0][19] - Azevedo & Travassos Energia S.A. (AZTE3)
# [4][0][20] - Azevedo & Travassos S.A. (AZEV4)
# [4][0][21] - Azul S.A. (AZUL4)
# [4][0][22] - Azzas 2154 S.A. (AZZA3)
# [4][0][23] - B3 S.A. - Brasil, Bolsa, Balcão (B3SA3)
# [4][0][24] - BB Seguridade Participações S.A. (BBSE3)
# [4][0][25] - BRB - Banco de Brasília S.A. (BSLI4)
# [4][0][26] - BRF S.A. (BRFS3)
# [4][0][27] - BRISANET    ON      NM (BRST3)
# [4][0][28] - Bahema Educação S.A. (BIED3)
# [4][0][29] - Banco ABC Brasil S.A. (ABCB4)
# [4][0][30] - Banco BMG S.A. (BMGB4)
# [4][0][31] - Banco BTG Pactual S.A. (BPAC3)
# [4][0][32] - Banco Bradesco S.A. (BBDC4)
# [4][0][33] - Banco Mercantil do Brasil S.A. (BMEB4)
# [4][0][34] - Banco Pan S.A. (BPAN4)
# [4][0][35] - Banco Pine S.A. (PINE4)
# [4][0][36] - Banco Santander (Brasil) S.A. (SANB3)
# [4][0][37] - Banco da Amazônia S.A. (BAZA3)
# [4][0][38] - Banco do Brasil S.A. (BBAS3)
# [4][0][39] - Banco do Estado de Sergipe S.A. (BGIP4)
# [4][0][40] - Banco do Estado do Rio Grande do Sul S.A. (BRSR3)
# [4][0][41] - Banco do Nordeste do Brasil S.A. (BNBR3)
# [4][0][42] - Banestes S.A - Banco do Estado do Espírito Santo (BEES3)
# [4][0][43] - Bemobi Mobile Tech S.A. (BMOB3)
# [4][0][44] - Bicicletas Monark S.A. (BMKS3)
# [4][0][45] - Biomm S.A. (BIOM3)
# [4][0][46] - Blau Farmacêutica S.A. (BLAU3)
# [4][0][47] - Boa Safra Sementes S.A. (SOJA3)
# [4][0][48] - Bombril S.A. (BOBR4)
# [4][0][49] - Bradespar S.A. (BRAP4)
# [4][0][50] - BrasilAgro - Companhia Brasileira de Propriedades Agrícolas (AGRO3)
# [4][0][51] - Braskem S.A. (BRKM3)
# [4][0][52] - Brava Energia S.A. (BRAV3)
# [4][0][53] - C&A Modas S.A. (CEAB3)
# [4][0][54] - CCR S.A. (CCRO3)
# [4][0][55] - CM Hospitalar S/A (VVEO3)
# [4][0][56] - CPFL Energia S.A. (CPFE3)
# [4][0][57] - CSN Mineração S.A. (CMIN3)
# [4][0][58] - CSU Digital S.A. (CSUD3)
# [4][0][59] - CVC Brasil Operadora e Agência de Viagens S.A. (CVCB3)
# [4][0][60] - Caixa Seguridade Participações S.A. (CXSE3)
# [4][0][61] - Cambuci S.A. (CAMB3)
# [4][0][62] - Camil Alimentos S.A. (CAML3)
# [4][0][63] - Cemepe Investimentos S.A. (MAPT4)
# [4][0][64] - Centrais Elétricas Brasileiras S.A. - Eletrobrás (ELET3)
# [4][0][65] - Centrais Elétricas de Santa Catarina S.A. (CLSC4)
# [4][0][66] - Cia de Ferro Ligas da Bahia S.A. - FERBASA (FESA4)
# [4][0][67] - Cogna Educação S.A. (COGN3)
# [4][0][68] - Companhia Brasileira De Distribuicao (PCAR3)
# [4][0][69] - Companhia Brasileira de Alumínio (CBAV3)
# [4][0][70] - Companhia Energética de Brasília - CEB (CEBR3)
# [4][0][71] - Companhia Energética de Minas Gerais - CEMIG (CMIG4)
# [4][0][72] - Companhia Paranaense de Energia - COPEL (CPLE3)
# [4][0][73] - Companhia Siderúrgica Nacional (CSNA3)
# [4][0][74] - Companhia Tecidos Santanense Ltda. (CTSA4)
# [4][0][75] - Companhia de Eletricidade do Estado da Bahia - COELBA (CEEB3)
# [4][0][76] - Companhia de Fiação e Tecidos Cedro e Cachoeira S.A. (CEDO4)
# [4][0][77] - Companhia de Saneamento Básico do Estado de São Paulo - SABESP (SBSP3)
# [4][0][78] - Companhia de Saneamento de Minas Gerais (CSMG3)
# [4][0][79] - Companhia de Saneamento do Paraná - SANEPAR (SAPR4)
# [4][0][80] - Construtora Tenda S.A. (TEND3)
# [4][0][81] - Cosan S.A. (CSAN3)
# [4][0][82] - Cruzeiro do Sul Educacional S.A. (CSED3)
# [4][0][83] - Cury Construtora e Incorporadora S.A. (CURY3)
# [4][0][84] - Cyrela Brazil Realty S.A. Empreendimentos e Participações (CYRE3)
# [4][0][85] - Desktop S.A. (DESK3)
# [4][0][86] - Dexco S.A. (DXCO3)
# [4][0][87] - Dexxos Participações S.A. (DEXP3)
# [4][0][88] - Diagnósticos da América S.A. (DASA3)
# [4][0][89] - Dimed S.A. Distribuidora de Medicamentos (PNVL3)
# [4][0][90] - Direcional Engenharia S.A. (DIRR3)
# [4][0][91] - Dotz S.A. (DOTZ3)
# [4][0][92] - Döhler S.A. (DOHL4)
# [4][0][93] - EZTEC Empreendimentos e Participações S.A. (EZTC3)
# [4][0][94] - EcoRodovias Infraestrutura e Logística S.A. (ECOR3)
# [4][0][95] - Electro Aço Altona S.A. (EALT4)
# [4][0][96] - Elektro Redes S.A. (EKTR4)
# [4][0][97] - Eletromidia S.A. (ELMD3)
# [4][0][98] - Embpar Participacoes S.A. (EPAR3)
# [4][0][99] - Embraer S.A. (EMBR3)
# [4][0][100] - Empreendimentos Pague Menos S.A. (PGMN3)
# [4][0][101] - Empresa Metropolitana de Águas e Energia S.A. (EMAE4)
# [4][0][102] - Energisa S.A. (ENGI4)
# [4][0][103] - Eneva S.A. (ENEV3)
# [4][0][104] - Engie Brasil Energia S.A. (EGIE3)
# [4][0][105] - Enjoei S.A. (ENJU3)
# [4][0][106] - Equatorial Pará Distribuidora de Energia S.A. (EQPA3)
# [4][0][107] - Equatorial S.A. (EQTL3)
# [4][0][108] - Eternit S.A. (ETER3)
# [4][0][109] - Eucatex S.A. Indústria e Comércio (EUCA4)
# [4][0][110] - Even Construtora e Incorporadora S.A. (EVEN3)
# [4][0][111] - Fertilizantes Heringer S.A. (FHER3)
# [4][0][112] - Fica Empreendimentos Imobiliarios S.A (FIEI3)
# [4][0][113] - Fictor Alimentos S.A. (FICT3)
# [4][0][114] - Fleury S.A. (FLRY3)
# [4][0][115] - Fras-le S.A. (FRAS3)
# [4][0][116] - GPS Participações e Empreendimentos S.A. (GGPS3)
# [4][0][117] - Gafisa S.A. (GFSA3)
# [4][0][118] - Gerdau S.A. (GGBR4)
# [4][0][119] - Gol Linhas Aéreas Inteligentes S.A. (GOLL4)
# [4][0][120] - Grazziotin S.A. (CGRA3)
# [4][0][121] - Grendene S.A. (GRND3)
# [4][0][122] - Grupo Casas Bahia S.A. (BHIA3)
# [4][0][123] - Grupo Mateus S.A. (GMAT3)
# [4][0][124] - Grupo SBF S.A. (SBFG3)
# [4][0][125] - Guararapes Confecções S.A. (GUAR3)
# [4][0][126] - HAGA S/A Indústria e Comércio (HAGA4)
# [4][0][127] - HBR Realty Empreendimentos Imobiliários S.A. (HBRE3)
# [4][0][128] - Hapvida Participações e Investimentos S.A. (HAPV3)
# [4][0][129] - Helbor Empreendimentos S.A. (HBOR3)
# [4][0][130] - Hidrovias do Brasil S.A. (HBSA3)
# [4][0][131] - Hospital Mater Dei S.A. (MATD3)
# [4][0][132] - Hotéis Othon S.A. (HOOT4)
# [4][0][133] - Hypera S.A. (HYPE3)
# [4][0][134] - IRB-Brasil Resseguros S.A. (IRBR3)
# [4][0][135] - ISA Energía Brasil S.A (ISAE4)
# [4][0][136] - Iguatemi S.A. (IGTI3)
# [4][0][137] - Inepar S.A. Indústria e Construções (INEP3)
# [4][0][138] - Infracommerce CXaaS S.A. (IFCM3)
# [4][0][139] - Intelbras S.A. - Indústria de Telecomunicação Eletrônica Brasileira (INTB3)
# [4][0][140] - International Meal Company Alimentação S.A. (MEAL3)
# [4][0][141] - Iochpe-Maxion S.A. (MYPK3)
# [4][0][142] - Irani Papel e Embalagem S.A. (RANI3)
# [4][0][143] - Itaú Unibanco Holding S.A. (ITUB4)
# [4][0][144] - Itaúsa S.A. (ITSA4)
# [4][0][145] - JBS S.A. (JBSS3)
# [4][0][146] - JHSF Participações S.A. (JHSF3)
# [4][0][147] - JOSAPAR Joaquim Oliveira S.A. Participações (JOPA3)
# [4][0][148] - JSL S.A. (JSLG3)
# [4][0][149] - Jalles Machado S/A (JALL3)
# [4][0][150] - João Fortes Engenharia S.A. (JFEN3)
# [4][0][151] - Karsten S.A. (CTKA4)
# [4][0][152] - Kepler Weber S.A. (KEPL3)
# [4][0][153] - Klabin S.A. (KLBN4)
# [4][0][154] - LOG Commercial Properties e Participações S.A. (LOGG3)
# [4][0][155] - LPS Brasil - Consultoria de Imóveis S.A. (LPSB3)
# [4][0][156] - Lavvi Empreendimentos Imobiliários S.A. (LAVV3)
# [4][0][157] - Light S.A. (LIGT3)
# [4][0][158] - Livetech da Bahia Indústria e Comércio S.A. (LVTC3)
# [4][0][159] - Localiza Rent a Car S.A. (RENT3)
# [4][0][160] - Locaweb Serviços de Internet S.A. (LWSA3)
# [4][0][161] - Log-In Logística Intermodal S.A. (LOGN3)
# [4][0][162] - Lojas Quero-Quero S.A. (LJQQ3)
# [4][0][163] - Lojas Renner S.A. (LREN3)
# [4][0][164] - Lupatech S.A. (LUPA3)
# [4][0][165] - M. Dias Branco S.A. Indústria e Comércio de Alimentos (MDIA3)
# [4][0][166] - MAHLE Metal Leve S.A. (LEVE3)
# [4][0][167] - METISA Metalúrgica Timboense S.A. (MTSA4)
# [4][0][168] - MPM Corpóreos S.A. (ESPA3)
# [4][0][169] - MRV Engenharia e Participações S.A. (MRVE3)
# [4][0][170] - Magazine Luiza S.A. (MGLU3)
# [4][0][171] - Mangels Industrial S.A. (MGEL4)
# [4][0][172] - Marcopolo S.A. (POMO4)
# [4][0][173] - Marfrig Global Foods S.A. (MRFG3)
# [4][0][174] - Marisa Lojas S.A. (AMAR3)
# [4][0][175] - Melnick Desenvolvimento Imobiliário S.A. (MELK3)
# [4][0][176] - Metalurgica Gerdau S.A. (GOAU4)
# [4][0][177] - Metalúrgica Riosulense S.A. (RSUL4)
# [4][0][178] - Mills Locação, Serviços e Logística S.A. (MILS3)
# [4][0][179] - Minerva S.A. (BEEF3)
# [4][0][180] - Minupar Participações S.A. (MNPR3)
# [4][0][181] - Mitre Realty Empreendimentos e Participações S.A. (MTRE3)
# [4][0][182] - Mobly S.A. (MBLY3)
# [4][0][183] - Monteiro Aranha S.A. (MOAR3)
# [4][0][184] - Moura Dubeux Engenharia S.A. (MDNE3)
# [4][0][185] - Movida Participações S.A. (MOVI3)
# [4][0][186] - Multilaser Industrial S.A. (MLAS3)
# [4][0][187] - Multiplan Empreendimentos Imobiliários S.A. (MULT3)
# [4][0][188] - Méliuz S.A. (CASH3)
# [4][0][189] - Natura &Co Holding S.A. (NTCO3)
# [4][0][190] - Neoenergia S.A. (NEOE3)
# [4][0][191] - Neogrid Participações S.A. (NGRD3)
# [4][0][192] - Nexpe Participações S.A. (NEXP3)
# [4][0][193] - Nutriplant Indústria e Comércio S/A (NUTR3)
# [4][0][194] - OSX Brasil S.A. (OSXB3)
# [4][0][195] - OceanPact Serviços Marítimos S.A. (OPCT3)
# [4][0][196] - Odontoprev S.A. (ODPV3)
# [4][0][197] - Oi S.A. (OIBR3)
# [4][0][198] - Oncoclínicas do Brasil Serviços Médicos S.A. (ONCO3)
# [4][0][199] - Orizon Valorização de Resíduos S.A. (ORVR3)
# [4][0][200] - Ouro Fino Saúde Animal Participações S.A. (OFSA3)
# [4][0][201] - PBG S.A. (PTBL3)
# [4][0][202] - PDG Realty S.A. Empreendimentos e Participações (PDGR3)
# [4][0][203] - Padtec Holding S.A. (PDTC3)
# [4][0][204] - Paranapanema S.A. (PMAM3)
# [4][0][205] - Pet Center Comércio e Participações S.A. (PETZ3)
# [4][0][206] - Petroreconcavo S.A. (RECV3)
# [4][0][207] - Petróleo Brasileiro S.A. - Petrobras (PETR4)
# [4][0][208] - Pettenati S.A. Industria Têxtil (PTNT4)
# [4][0][209] - Plano & Plano Desenvolvimento Imobiliário S.A. (PLPL3)
# [4][0][210] - Porto Seguro S.A. (PSSA3)
# [4][0][211] - Positivo Tecnologia S.A. (POSI3)
# [4][0][212] - Priner Serviços Industriais S.A. (PRNR3)
# [4][0][213] - Prio S.A. (PRIO3)
# [4][0][214] - Profarma Distribuidora de Produtos Farmacêuticos S.A. (PFRM3)
# [4][0][215] - Qualicorp Consultoria e Corretora de Seguros S.A. (QUAL3)
# [4][0][216] - REAG Investimentos S.A. (REAG3)
# [4][0][217] - RNI Negócios Imobiliários S.A. (RDNI3)
# [4][0][218] - Raia Drogasil S.A. (RADL3)
# [4][0][219] - Randon S.A. Implementos e Participações (RAPT4)
# [4][0][220] - Raízen S.A. (RAIZ4)
# [4][0][221] - Recrusul S/A (RCSL4)
# [4][0][222] - Rede D'Or São Luiz S.A. (RDOR3)
# [4][0][223] - Rede Energia Participações S.A. (REDE3)
# [4][0][224] - Refinaria de Petróleos de Manguinhos S.A. (RPMG3)
# [4][0][225] - Renova Energia S.A. (RNEW4)
# [4][0][226] - Rio Paranapanema Energia S.A. (GEPA4)
# [4][0][227] - Romi S.A. (ROMI3)
# [4][0][228] - Rossi Residencial S.A. (RSID3)
# [4][0][229] - Rumo S.A. (RAIL3)
# [4][0][230] - SIMPAR S.A. (SIMH3)
# [4][0][231] - SLC Agrícola S.A. (SLCE3)
# [4][0][232] - Sansuy S.A. (SNSY3)
# [4][0][233] - Santos Brasil Participações S.A. (STBP3)
# [4][0][234] - Schulz S.A. (SHUL4)
# [4][0][235] - Sendas Distribuidora S.A. (ASAI3)
# [4][0][236] - Sequoia Logística e Transportes S.A. (SEQL3)
# [4][0][237] - Ser Educacional S.A. (SEER3)
# [4][0][238] - Serena Energia S.A. (SRNA3)
# [4][0][239] - Smartfit Escola de Ginástica e Dança S.A. (SMFT3)
# [4][0][240] - Suzano S.A. (SUZB3)
# [4][0][241] - Syn Prop & Tech S.A. (SYNE3)
# [4][0][242] - São Carlos Empreendimentos e Participações S.A. (SCAR3)
# [4][0][243] - São Martinho S.A. (SMTO3)
# [4][0][244] - T4F Entretenimento S.A. (SHOW3)
# [4][0][245] - TC S.A. (TRAD3)
# [4][0][246] - TIM S.A. (TIMS3)
# [4][0][247] - TOTVS S.A. (TOTS3)
# [4][0][248] - Taurus Armas S.A. (TASA4)
# [4][0][249] - Technos S.A. (TECN3)
# [4][0][250] - Tecnisa S.A. (TCSA3)
# [4][0][251] - Tegma Gestão Logística S.A. (TGMA3)
# [4][0][252] - Telecomunicações Brasileiras S.A. - Telebras (TELB4)
# [4][0][253] - Telefônica Brasil S.A. (VIVT3)
# [4][0][254] - Terra Santa Propriedades Agrícolas S.A. (LAND3)
# [4][0][255] - Track & Field Co S.A. (TFCO4)
# [4][0][256] - Transmissora Aliança de Energia Elétrica S.A. (TAEE4)
# [4][0][257] - Trisul S.A. (TRIS3)
# [4][0][258] - Triunfo Participações e Investimentos S.A. (TPIS3)
# [4][0][259] - Três Tentos Agroindustrial S/A (TTEN3)
# [4][0][260] - Tupy S.A. (TUPY3)
# [4][0][261] - Têxtil Renauxview S.A. (TXRX4)
# [4][0][262] - Ultrapar Participações S.A. (UGPA3)
# [4][0][263] - Unicasa Indústria de Móveis S.A. (UCAS3)
# [4][0][264] - Unifique Telecomunicações S.A. (FIQE3)
# [4][0][265] - Unipar Carbocloro S.A. (UNIP3)
# [4][0][266] - Usinas Siderúrgicas de Minas Gerais S.A. (USIM3)
# [4][0][267] - Vale S.A. (VALE3)
# [4][0][268] - Valid Soluções S.A. (VLID3)
# [4][0][269] - Vamos Locação de Caminhões, Máquinas e Equipamentos S.A. (VAMO3)
# [4][0][270] - Veste S.A. Estilo (VSTE3)
# [4][0][271] - Vibra Energia S.A. (VBBR3)
# [4][0][272] - Vitru Brasil Empreendimentos, Participações e Comércio S.A (VTRU3)
# [4][0][273] - Vittia S.A. (VITT3)
# [4][0][274] - Vivara Participações S.A. (VIVA3)
# [4][0][275] - Viver Incorporadora e Construtora S.A. (VIVR3)
# [4][0][276] - Vulcabras S.A. (VULC3)
# [4][0][277] - WEG S.A. (WEGE3)
# [4][0][278] - WLM Participações e Comércio de Máquinas e Veículos S.A. (WLMM4)
# [4][0][279] - Westwing Comércio Varejista S.A. (WEST3)
# [4][0][280] - Whirlpool S.A. (WHRL3)
# [4][0][281] - Wilson Sons S.A. (PORT3)
# [4][0][282] - Wiz Co Participações e Corretagem de Seguros S.A. (WIZC3)
# [4][0][283] - Yduqs Participações S.A. (YDUQ3)
# [4][0][284] - Zamp S.A. (ZAMP3)
# [4][0][285] - d1000 Varejo Farma Participações S.A. (DMVF3)
# [4][0][286] - Ânima Holding S.A. (ANIM3)
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# [4][1] - Brazilian Depositary Receipt (BDR)
# [4][1][0] - 3M Company (MMMC34)
# [4][1][1] - ABDEN SILV  DRE (SIVR39)
# [4][1][2] - ASML Holding N.V. (ASML34)
# [4][1][3] - AT&T Inc. (ATTB34)
# [4][1][4] - AbbVie Inc. (ABBV34)
# [4][1][5] - Abbott Laboratories (ABTT34)
# [4][1][6] - Adobe Inc. (ADBE34)
# [4][1][7] - Advance Auto Parts, Inc. (A1AP34)
# [4][1][8] - Advanced Micro Devices, Inc. (A1MD34)
# [4][1][9] - Afya Limited (A2FY34)
# [4][1][10] - Airbnb, Inc. (AIRB34)
# [4][1][11] - Albemarle Corporation (A1LB34)
# [4][1][12] - Alexandria Real Estate Equities, Inc. (A1RE34)
# [4][1][13] - Alibaba Group Holding Limited (BABA34)
# [4][1][14] - Almacenes Éxito S.A. (EXCO32)
# [4][1][15] - Alnylam Pharmaceuticals, Inc. (A1LN34)
# [4][1][16] - Alphabet Inc. (GOGL34)
# [4][1][17] - Alphabet Inc. (GOGL35)
# [4][1][18] - Altria Group, Inc. (MOOO34)
# [4][1][19] - Amazon.com, Inc. (AMZO34)
# [4][1][20] - American Airlines Group Inc. (AALL34)
# [4][1][21] - American Electric Power Company, Inc. (A1EP34)
# [4][1][22] - American Express Company (AXPB34)
# [4][1][23] - American International Group, Inc. (AIGB34)
# [4][1][24] - American Tower Corporation (T1OW34)
# [4][1][25] - American Water Works Company, Inc. (A1WK34)
# [4][1][26] - Ameriprise Financial, Inc. (A1MP34)
# [4][1][27] - Amgen Inc. (AMGN34)
# [4][1][28] - Amphenol Corporation (A1PH34)
# [4][1][29] - Anheuser-Busch InBev SA/NV (ABUD34)
# [4][1][30] - Annaly Capital Management, Inc. (N2LY34)
# [4][1][31] - Apartment Investment and Management Company (A1IV34)
# [4][1][32] - Apple Inc. (AAPL34)
# [4][1][33] - Applied Materials, Inc. (A1MT34)
# [4][1][34] - ArcelorMittal S.A. (ARMT34)
# [4][1][35] - Ares Management Corporation (A2RE34)
# [4][1][36] - Arista Networks Inc (A1NE34)
# [4][1][37] - AstraZeneca PLC (A1ZN34)
# [4][1][38] - Atlassian Corporation (T1AM34)
# [4][1][39] - Aura Minerals Inc. (AURA33)
# [4][1][40] - AutoZone, Inc. (AZOI34)
# [4][1][41] - Autodesk, Inc. (A1UT34)
# [4][1][42] - Axon Enterprise, Inc. (A2XO34)
# [4][1][43] - BILL Holdings, Inc. (B2HI34)
# [4][1][44] - BKR 1 3 YRTRDRE (BSHY39)
# [4][1][45] - BKR 1 5YGRCODRE (BIGS39)
# [4][1][46] - BKR 20YR TRSDRE (BTLT39)
# [4][1][47] - BKR 3 7 YRTRDRE (BIEI39)
# [4][1][48] - BKR 7 10 YRTDRE (BIYT39)
# [4][1][49] - BKR BITCOIN DRE (IBIT39)
# [4][1][50] - BKR CHILE   DRE (BECH39)
# [4][1][51] - BKR COMT ROLDRE (BCOM39)
# [4][1][52] - BKR ETHEREUMDRE (ETHA39)
# [4][1][53] - BKR FLOT RTEDRE (BTFL39)
# [4][1][54] - BKR MOD ALOCDRE (BAOM39)
# [4][1][55] - BKR MS EAFE DRE (BSCZ39)
# [4][1][56] - BKR SHORT TRDRE (BSHV39)
# [4][1][57] - BKR TIP     DRE (BTIP39)
# [4][1][58] - BKR US TREASDRE (BGOV39)
# [4][1][59] - BP p.l.c. (B1PP34)
# [4][1][60] - Baidu, Inc. (BIDU34)
# [4][1][61] - Banco Bilbao Vizcaya Argentaria, S.A. (BILB34)
# [4][1][62] - Banco Santander, S.A. (BCSA34)
# [4][1][63] - Banco Santander-Chile (B1SA34)
# [4][1][64] - Bancolombia S.A. (C2OL34)
# [4][1][65] - Bank of America Corporation (BOAC34)
# [4][1][66] - Barclays PLC (B1CS34)
# [4][1][67] - Berkshire Hathaway Inc. (BERK34)
# [4][1][68] - Best Buy Co., Inc. (BBYY34)
# [4][1][69] - Beyond Meat, Inc. (B2YN34)
# [4][1][70] - Bilibili Inc. (B1IL34)
# [4][1][71] - BioNTech SE (B1NT34)
# [4][1][72] - BlackRock Institutional Trust Company NA (BIJS39)
# [4][1][73] - BlackRock, Inc. (BLAK34)
# [4][1][74] - Block, Inc. (X1YZ34)
# [4][1][75] - Booking Holdings Inc. (BKNG34)
# [4][1][76] - Boston Scientific Corporation (B1SX34)
# [4][1][77] - Bread Financial Holdings, Inc. (A1LL34)
# [4][1][78] - Bristol-Myers Squibb Company (BMYB34)
# [4][1][79] - British American Tobacco p.l.c. (B1TI34)
# [4][1][80] - Broadcom Inc. (AVGO34)
# [4][1][81] - Brookfield Corporation (B1AM34)
# [4][1][82] - Burlington Stores, Inc. (B2UR34)
# [4][1][83] - CACI International Inc (C2AC34)
# [4][1][84] - CBRE Group, Inc. (C1BR34)
# [4][1][85] - CME Group Inc. (CHME34)
# [4][1][86] - CRH PLC     DRN (C1RH34)
# [4][1][87] - CVS Health Corporation (CVSH34)
# [4][1][88] - Canadian National Railway Company (CNIC34)
# [4][1][89] - Canadian Pacific Kansas City Limited (CPRL34)
# [4][1][90] - Carnival Corporation & plc (C1CL34)
# [4][1][91] - Caterpillar Inc. (CATP34)
# [4][1][92] - CenterPoint Energy, Inc. (C1NP34)
# [4][1][93] - Cerence Inc. (C2RN34)
# [4][1][94] - Charter Communications, Inc. (CHCM34)
# [4][1][95] - Chevron Corporation (CHVX34)
# [4][1][96] - Chipotle Mexican Grill, Inc. (C1MG34)
# [4][1][97] - Chubb Limited (C1BL34)
# [4][1][98] - Chunghwa Telecom Co., Ltd. (C1HT34)
# [4][1][99] - Cisco Systems, Inc. (CSCO34)
# [4][1][100] - Citigroup Inc. (CTGP34)
# [4][1][101] - Citizens Financial Group, Inc. (C1FG34)
# [4][1][102] - Cloudflare, Inc. (N2ET34)
# [4][1][103] - Clover Health Investments, Corp. (CLOV34)
# [4][1][104] - Coca-Cola FEMSA, S.A.B. de C.V. (C2CA34)
# [4][1][105] - Coinbase Global, Inc. (C2OI34)
# [4][1][106] - Colgate-Palmolive Company (COLG34)
# [4][1][107] - Comcast Corporation (CMCS34)
# [4][1][108] - ConocoPhillips (COPH34)
# [4][1][109] - Copart, Inc. (C1PR34)
# [4][1][110] - Costco Wholesale Corporation (COWC34)
# [4][1][111] - Coty Inc. (COTY34)
# [4][1][112] - Coursera, Inc. (C2OU34)
# [4][1][113] - CrowdStrike Holdings, Inc. (C2RW34)
# [4][1][114] - DTE Energy Company (D1TE34)
# [4][1][115] - DaVita Inc. (DVAI34)
# [4][1][116] - Danaher Corporation (DHER34)
# [4][1][117] - Darden Restaurants, Inc. (D1RI34)
# [4][1][118] - Deere & Company (DEEC34)
# [4][1][119] - Dell Technologies Inc. (D1EL34)
# [4][1][120] - Deutsche Bank Aktiengesellschaft (DBAG34)
# [4][1][121] - DexCom, Inc. (D1EX34)
# [4][1][122] - Diageo plc (DEOP34)
# [4][1][123] - Digital Realty Trust, Inc. (D1LR34)
# [4][1][124] - DocuSign, Inc. (D1OC34)
# [4][1][125] - Dollar General Corporation (DGCO34)
# [4][1][126] - Dollar Tree, Inc. (DLTR34)
# [4][1][127] - DoorDash, Inc. (D2AS34)
# [4][1][128] - Dover Corporation (D1OV34)
# [4][1][129] - Dow Inc. (D1OW34)
# [4][1][130] - Doximity, Inc. (D2OC34)
# [4][1][131] - DraftKings Inc. (D2KN34)
# [4][1][132] - DuPont de Nemours, Inc. (DDNB34)
# [4][1][133] - EVERTEC INC DR1 (EVTC31)
# [4][1][134] - EXPERIAN PLCDR1 (EXPB31)
# [4][1][135] - Eastman Chemical Company (E1MN34)
# [4][1][136] - Ecopetrol S.A. (E1CO34)
# [4][1][137] - Edwards Lifesciences Corporation (E1WL34)
# [4][1][138] - Elastic N.V. (E2ST34)
# [4][1][139] - Electronic Arts Inc. (EAIN34)
# [4][1][140] - Eli Lilly and Company (LILY34)
# [4][1][141] - Enphase Energy, Inc. (E2NP34)
# [4][1][142] - Entegris, Inc. (E2NT34)
# [4][1][143] - Equinix, Inc. (EQIX34)
# [4][1][144] - Equinor ASA (E1QN34)
# [4][1][145] - Euronet Worldwide, Inc. (E2EF34)
# [4][1][146] - Exelixis, Inc. (E2XE34)
# [4][1][147] - Exelon Corporation (E1XC34)
# [4][1][148] - Expedia Group, Inc. (EXGR34)
# [4][1][149] - Exxon Mobil Corporation (EXXO34)
# [4][1][150] - FMC Corporation (F1MC34)
# [4][1][151] - FT HCAREALPHDRE (BFXH39)
# [4][1][152] - Fair Isaac Corporation (F2IC34)
# [4][1][153] - Fastly, Inc. (F1SL34)
# [4][1][154] - FedEx Corporation (FDXB34)
# [4][1][155] - First Solar, Inc. (FSLR34)
# [4][1][156] - Fiserv, Inc. (F1IS34)
# [4][1][157] - Ford Motor Company (FDMO34)
# [4][1][158] - Fortinet, Inc. (F1TN34)
# [4][1][159] - Franco-Nevada Corporation (F2NV34)
# [4][1][160] - Freeport-McMoRan Inc. (FCXO34)
# [4][1][161] - G2D Investments, Ltd. (G2DI33)
# [4][1][162] - GDS Holdings Limited (G1DS34)
# [4][1][163] - GE VERNOVA  DRN ED (G2EV34)
# [4][1][164] - GLOBANT SA  DRN (G1LO34)
# [4][1][165] - GP Investments, Ltd. (GPIV33)
# [4][1][166] - GX AI TECH  DRE (BAIQ39)
# [4][1][167] - GX BLOCKCHAIDRE (BKCH39)
# [4][1][168] - GX GENOMBIOTDRE (BGNO39)
# [4][1][169] - Galapagos NV (G1LP34)
# [4][1][170] - General Electric Company (GEOO34)
# [4][1][171] - General Mills, Inc. (G1MI34)
# [4][1][172] - General Motors Company (GMCO34)
# [4][1][173] - GeoPark Limited (GPRK34)
# [4][1][174] - Gilead Sciences, Inc. (GILD34)
# [4][1][175] - Global Payments Inc. (G1PI34)
# [4][1][176] - Global X Funds (BBUG39)
# [4][1][177] - Global X Funds (BCPX39)
# [4][1][178] - Global X Funds (BDVD39)
# [4][1][179] - Global X Funds (BHER39)
# [4][1][180] - Global X Funds (BOTZ39)
# [4][1][181] - Global X Funds (BQYL39)
# [4][1][182] - Global X Funds (BSDV39)
# [4][1][183] - Global X Funds (BSIL39)
# [4][1][184] - Global X Funds (BURA39)
# [4][1][185] - Globus Medical, Inc. (G2ME34)
# [4][1][186] - GoPro, Inc. (GPRO34)
# [4][1][187] - Gold Fields Limited (G1FI34)
# [4][1][188] - H&R Block, Inc. (H1RB34)
# [4][1][189] - HEICO Corporation (H1EI34)
# [4][1][190] - HP Inc. (HPQB34)
# [4][1][191] - HSBC Holdings plc (H1SB34)
# [4][1][192] - Harley-Davidson, Inc. (H1OG34)
# [4][1][193] - Honda Motor Co., Ltd. (HOND34)
# [4][1][194] - Howmet Aerospace Inc. (ARNC34)
# [4][1][195] - HubSpot, Inc. (H2UB34)
# [4][1][196] - Humana Inc. (H1UM34)
# [4][1][197] - IDEX Corporation (I1EX34)
# [4][1][198] - ING Groep N.V. (INGG34)
# [4][1][199] - Illumina, Inc. (I1LM34)
# [4][1][200] - Ingredion Incorporated (I2NG34)
# [4][1][201] - Intel Corporation (ITLC34)
# [4][1][202] - Inter & Co, Inc. (INBR32)
# [4][1][203] - International Business Machines Corporation (IBMB34)
# [4][1][204] - International Paper Company (I1PC34)
# [4][1][205] - Intuitive Surgical, Inc. (I1SR34)
# [4][1][206] - Invesco Ltd. (I1VZ34)
# [4][1][207] - Ishares Core Msci Eafe ETF (BIEF39)
# [4][1][208] - Ishares Core Msci Emerging Markets ETF (BIEM39)
# [4][1][209] - Ishares Core Msci Europe ETF (BIEU39)
# [4][1][210] - Ishares Core S&P 500 Etf (BIVB39)
# [4][1][211] - Ishares Core S&P Mid-Cap Etf (BIJH39)
# [4][1][212] - Ishares Core S&P Small-Cap Etf (BIJR39)
# [4][1][213] - Ishares Core S&P Total Us Stock Market Etf (BITO39)
# [4][1][214] - Ishares Exponential Technologies ETF (BXTC39)
# [4][1][215] - Ishares Global Healthcare Etf (BIXJ39)
# [4][1][216] - Ishares Global Tech ETF (BIXN39)
# [4][1][217] - Ishares Gold Trust (BIAU39)
# [4][1][218] - Ishares Msci Acwi ETF (BACW39)
# [4][1][219] - Ishares Msci All Country Asia Ex Japan ETF (BAAX39)
# [4][1][220] - Ishares Msci Brazil ETF (BEWZ39)
# [4][1][221] - Ishares Msci China Etf (BCHI39)
# [4][1][222] - Ishares Msci Eafe ETF (BEFA39)
# [4][1][223] - Ishares Msci Emerging Markets ETF (BEEM39)
# [4][1][224] - Ishares Msci Eurozone ETF (BEZU39)
# [4][1][225] - Ishares Msci Germany ETF (BEWG39)
# [4][1][226] - Ishares Msci Hong Kong Etf (BEWH39)
# [4][1][227] - Ishares Msci India Etf (BNDA39)
# [4][1][228] - Ishares Msci Japan Etf (BEWJ39)
# [4][1][229] - Ishares Msci Taiwan ETF (BEWT39)
# [4][1][230] - Ishares Msci United Kingdom Etf (BEWU39)
# [4][1][231] - Ishares Nasdaq Biotechnology Etf (BIBB39)
# [4][1][232] - Ishares Russell 2000 Etf (BIWM39)
# [4][1][233] - Ishares Select Dividend Etf (BDVY39)
# [4][1][234] - Ishares Silver Trust (BSLV39)
# [4][1][235] - Ishares US Technology ETF (BIYW39)
# [4][1][236] - Ishares Us Aerospace & Defense ETF (BAER39)
# [4][1][237] - JD.com, Inc. (JDCO34)
# [4][1][238] - JPMorgan Chase & Co. (JPMC34)
# [4][1][239] - Jabil Inc. (J2BL34)
# [4][1][240] - Johnson & Johnson (JNJB34)
# [4][1][241] - Juniper Networks, Inc. (J1NP34)
# [4][1][242] - KLA Corporation (K1LA34)
# [4][1][243] - KR CSI CHINADRE (BKWB39)
# [4][1][244] - Kimberly-Clark Corporation (KMBB34)
# [4][1][245] - Kingsoft Cloud Holdings Limited (K2CG34)
# [4][1][246] - Kohl's Corporation (K1SS34)
# [4][1][247] - L3Harris Technologies, Inc. (L1HX34)
# [4][1][248] - Lam Research Corporation (L1RC34)
# [4][1][249] - Las Vegas Sands Corp. (L1VS34)
# [4][1][250] - Leggett & Platt, Incorporated (L1EG34)
# [4][1][251] - Liberty Broadband Corporation (LBRD34)
# [4][1][252] - Live Nation Entertainment, Inc. (L1YV34)
# [4][1][253] - Lloyds Banking Group plc (L1YG34)
# [4][1][254] - Lumen Technologies, Inc. (L1MN34)
# [4][1][255] - LyondellBasell Industries N.V. (L1YB34)
# [4][1][256] - MP Materials Corp. (M2PM34)
# [4][1][257] - MSCI Inc. (M1SC34)
# [4][1][258] - Macy's, Inc. (MACY34)
# [4][1][259] - Marriott International, Inc. (M1TT34)
# [4][1][260] - Marsh & McLennan Companies, Inc. (M1MC34)
# [4][1][261] - Marvell Technology, Inc. (M2RV34)
# [4][1][262] - Mastercard Incorporated (MSCD34)
# [4][1][263] - McDonald's Corporation (MCDC34)
# [4][1][264] - McKesson Corporation (M1CK34)
# [4][1][265] - Medical Properties Trust, Inc. (M2PW34)
# [4][1][266] - MercadoLibre, Inc. (MELI34)
# [4][1][267] - Merck & Co., Inc. (MRCK34)
# [4][1][268] - Meta Platforms, Inc. (M1TA34)
# [4][1][269] - MicroStrategy Incorporated (M2ST34)
# [4][1][270] - Microchip Technology Incorporated (M1CH34)
# [4][1][271] - Micron Technology, Inc. (MUTC34)
# [4][1][272] - Microsoft Corporation (MSFT34)
# [4][1][273] - Mitsubishi UFJ Financial Group, Inc. (M1UF34)
# [4][1][274] - Moderna, Inc. (M1RN34)
# [4][1][275] - Mondelez International, Inc. (MDLZ34)
# [4][1][276] - MongoDB, Inc. (M1DB34)
# [4][1][277] - Monster Beverage Corporation (M1NS34)
# [4][1][278] - Moody's Corporation (MCOR34)
# [4][1][279] - Morgan Stanley (MSBR34)
# [4][1][280] - NATL STORAGEDRN ED (NSAT34)
# [4][1][281] - NIKE, Inc. (NIKE34)
# [4][1][282] - NVIDIA Corporation (NVDC34)
# [4][1][283] - Nasdaq, Inc. (N1DA34)
# [4][1][284] - NatWest Group plc (N1WG34)
# [4][1][285] - NetApp, Inc. (N1TA34)
# [4][1][286] - NetEase, Inc. (NETE34)
# [4][1][287] - Netflix, Inc. (NFLX34)
# [4][1][288] - Neurocrine Biosciences, Inc. (N1BI34)
# [4][1][289] - New Oriental Education & Technology Group Inc. (E1DU34)
# [4][1][290] - Newell Brands Inc. (N1WL34)
# [4][1][291] - Newmont Corporation (N1EM34)
# [4][1][292] - NextEra Energy, Inc. (NEXT34)
# [4][1][293] - NiSource Inc. (N1IS34)
# [4][1][294] - Nokia Oyj (NOKI34)
# [4][1][295] - Northrop Grumman Corporation (NOCG34)
# [4][1][296] - Novartis AG (N1VS34)
# [4][1][297] - Novo Nordisk A/S (N1VO34)
# [4][1][298] - Nu Holdings Ltd. (ROXO34)
# [4][1][299] - Nucor Corporation (N1UE34)
# [4][1][300] - O'Reilly Automotive, Inc. (ORLY34)
# [4][1][301] - ORIX Corporation (I1XC34)
# [4][1][302] - Occidental Petroleum Corporation (OXYP34)
# [4][1][303] - Okta, Inc. (O1KT34)
# [4][1][304] - Oracle Corporation (ORCL34)
# [4][1][305] - PACCAR Inc (P1AC34)
# [4][1][306] - PDD Holdings Inc. (P1DD34)
# [4][1][307] - PPG Industries, Inc. (P1PG34)
# [4][1][308] - Packaging Corporation of America (P1KG34)
# [4][1][309] - PagSeguro Digital Ltd. (PAGS34)
# [4][1][310] - Palantir Technologies Inc. (P2LT34)
# [4][1][311] - Palo Alto Networks, Inc. (P2AN34)
# [4][1][312] - Paramount Global (C1BS34)
# [4][1][313] - Patria Investments Limited (P2AX34)
# [4][1][314] - PayPal Holdings, Inc. (PYPL34)
# [4][1][315] - Penumbra, Inc. (P2NB34)
# [4][1][316] - PepsiCo, Inc. (PEPB34)
# [4][1][317] - Pfizer Inc. (PFIZ34)
# [4][1][318] - Philip Morris International Inc. (PHMO34)
# [4][1][319] - Pinterest, Inc. (P2IN34)
# [4][1][320] - Prologis, Inc. (P1LD34)
# [4][1][321] - Prudential Financial, Inc. (P1DT34)
# [4][1][322] - QUALCOMM Incorporated (QCOM34)
# [4][1][323] - RH (R2HH34)
# [4][1][324] - RTX Corporation (RYTT34)
# [4][1][325] - Ralph Lauren Corporation (R1LC34)
# [4][1][326] - Realty Income Corporation (R1IN34)
# [4][1][327] - Redfin Corporation (R2DF34)
# [4][1][328] - Regeneron Pharmaceuticals, Inc. (REGN34)
# [4][1][329] - Regions Financial Corporation (R1FC34)
# [4][1][330] - ResMed Inc. (R1MD34)
# [4][1][331] - Rio Tinto Group (RIOT34)
# [4][1][332] - Roblox Corporation (R2BL34)
# [4][1][333] - Rockwell Automation, Inc. (R1OK34)
# [4][1][334] - Roku, Inc. (R1KU34)
# [4][1][335] - Ross Stores, Inc. (ROST34)
# [4][1][336] - S&P Global Inc. (SPGI34)
# [4][1][337] - SL Green Realty Corp. (S1LG34)
# [4][1][338] - STAG Industrial, Inc. (S2TA34)
# [4][1][339] - STMicroelectronics N.V. (STMN34)
# [4][1][340] - Salesforce, Inc. (SSFO34)
# [4][1][341] - Sarepta Therapeutics, Inc. (S1RP34)
# [4][1][342] - Schlumberger Limited (SLBG34)
# [4][1][343] - Sea Limited (S2EA34)
# [4][1][344] - Sempra (S1RE34)
# [4][1][345] - ServiceNow, Inc. (N1OW34)
# [4][1][346] - Shopify Inc. (S2HO34)
# [4][1][347] - Sigma Lithium Corporation (S2GM34)
# [4][1][348] - Simon Property Group, Inc. (SIMN34)
# [4][1][349] - Snap Inc. (S2NA34)
# [4][1][350] - Snowflake Inc. (S2NW34)
# [4][1][351] - SolarEdge Technologies, Inc. (S2ED34)
# [4][1][352] - Sony Group Corporation (SNEC34)
# [4][1][353] - Southwest Airlines Co. (S1OU34)
# [4][1][354] - Spotify Technology S.A. (S1PO34)
# [4][1][355] - Sprouts Farmers Market, Inc. (S2FM34)
# [4][1][356] - Stanley Black & Decker, Inc. (S1WK34)
# [4][1][357] - Starbucks Corporation (SBUB34)
# [4][1][358] - Starwood Property Trust, Inc. (S2TW34)
# [4][1][359] - State Street Corporation (S1TT34)
# [4][1][360] - StoneCo Ltd. (STOC34)
# [4][1][361] - Stride, Inc. (L2RN34)
# [4][1][362] - Sun Communities, Inc. (S2UI34)
# [4][1][363] - Synopsys, Inc. (S1NP34)
# [4][1][364] - T-Mobile US, Inc. (T1MU34)
# [4][1][365] - T. Rowe Price Group, Inc. (T1RO34)
# [4][1][366] - TAL Education Group (T1AL34)
# [4][1][367] - Taiwan Semiconductor Manufacturing Company Limited (TSMC34)
# [4][1][368] - Take-Two Interactive Software, Inc. (T1TW34)
# [4][1][369] - Target Corporation (TGTB34)
# [4][1][370] - Teladoc Health, Inc. (T2DH34)
# [4][1][371] - Telefónica, S.A. (TLNC34)
# [4][1][372] - Ternium S.A. (TXSA34)
# [4][1][373] - Tesla, Inc. (TSLA34)
# [4][1][374] - Texas Instruments Incorporated (TEXA34)
# [4][1][375] - The AES Corporation (A1ES34)
# [4][1][376] - The Bank of New York Mellon Corporation (BONY34)
# [4][1][377] - The Boeing Company (BOEI34)
# [4][1][378] - The Charles Schwab Corporation (SCHW34)
# [4][1][379] - The Coca-Cola Company (COCA34)
# [4][1][380] - The Gap, Inc. (GPSI34)
# [4][1][381] - The Goldman Sachs Group, Inc. (GSGI34)
# [4][1][382] - The Home Depot, Inc. (HOME34)
# [4][1][383] - The Kraft Heinz Company (KHCB34)
# [4][1][384] - The Kroger Co. (K1RC34)
# [4][1][385] - The Mosaic Company (MOSC34)
# [4][1][386] - The Procter & Gamble Company (PGCO34)
# [4][1][387] - The Progressive Corporation (P1GR34)
# [4][1][388] - The Sherwin-Williams Company (S1HW34)
# [4][1][389] - The TJX Companies, Inc. (TJXC34)
# [4][1][390] - The Trade Desk, Inc. (T2TD34)
# [4][1][391] - The Travelers Companies, Inc. (TRVC34)
# [4][1][392] - The Walt Disney Company (DISB34)
# [4][1][393] - The Western Union Company (WUNI34)
# [4][1][394] - The Williams Companies, Inc. (W1MB34)
# [4][1][395] - Thermo Fisher Scientific Inc. (TMOS34)
# [4][1][396] - Toyota Motor Corporation (TMCO34)
# [4][1][397] - Tractor Supply Company (T1SC34)
# [4][1][398] - Transocean Ltd. (RIGG34)
# [4][1][399] - Trip.com Group Limited (CRIP34)
# [4][1][400] - Tripadvisor, Inc. (T1RI34)
# [4][1][401] - Twilio Inc. (T1WL34)
# [4][1][402] - Tyson Foods, Inc. (TSNF34)
# [4][1][403] - U.S. Bancorp (USBC34)
# [4][1][404] - Uber Technologies, Inc. (U1BE34)
# [4][1][405] - UiPath Inc. (P2AT34)
# [4][1][406] - Ulta Beauty, Inc. (U1LT34)
# [4][1][407] - Under Armour, Inc. (U1AI34)
# [4][1][408] - Unilever PLC (ULEV34)
# [4][1][409] - United Airlines Holdings, Inc. (U1AL34)
# [4][1][410] - United Natural Foods, Inc. (U2NF34)
# [4][1][411] - United Parcel Service, Inc. (UPSS34)
# [4][1][412] - United Rentals, Inc. (U1RI34)
# [4][1][413] - United States Steel Corporation (USSX34)
# [4][1][414] - UnitedHealth Group Incorporated (UNHH34)
# [4][1][415] - Unity Software Inc. (U2ST34)
# [4][1][416] - Upstart Holdings, Inc. (U2PS34)
# [4][1][417] - VTEX        DRN (V2TX34)
# [4][1][418] - VanEck Gold Miners ETF (GDXB39)
# [4][1][419] - Veeva Systems Inc. (V2EE34)
# [4][1][420] - VeriSign, Inc. (VRSN34)
# [4][1][421] - Verizon Communications Inc. (VERZ34)
# [4][1][422] - Vertex Pharmaceuticals Incorporated (VRTX34)
# [4][1][423] - Visa Inc. (VISA34)
# [4][1][424] - Vodafone Group Public Limited Company (V1OD34)
# [4][1][425] - W. R. Berkley Corporation (W1RB34)
# [4][1][426] - W.W. Grainger, Inc. (G1WW34)
# [4][1][427] - WPP plc (W1PP34)
# [4][1][428] - Walmart Inc. (WALM34)
# [4][1][429] - Warner Bros. Discovery, Inc. (W1BD34)
# [4][1][430] - Warner Music Group Corp. (W1MG34)
# [4][1][431] - Wayfair Inc. (W2YF34)
# [4][1][432] - Weibo Corporation (W1BO34)
# [4][1][433] - Wells Fargo & Company (WFCO34)
# [4][1][434] - Welltower Inc. (W1EL34)
# [4][1][435] - Westinghouse Air Brake Technologies Corporation (W1AB34)
# [4][1][436] - Whirlpool Corporation (W1HR34)
# [4][1][437] - Wix.com Ltd. (W1IX34)
# [4][1][438] - Wolfspeed, Inc. (W2OL34)
# [4][1][439] - XP Inc. (XPBR31)
# [4][1][440] - Xerox Holdings Corporation (XRXB34)
# [4][1][441] - YPF Sociedad Anónima (Y2PF34)
# [4][1][442] - Yum! Brands, Inc. (YUMR34)
# [4][1][443] - Zebra Technologies Corporation (Z1BR34)
# [4][1][444] - Ziff Davis, Inc. (Z2DV34)
# [4][1][445] - Zoetis Inc. (Z1TS34)
# [4][1][446] - Zoom Communications Inc. (Z1OM34)
# [4][1][447] - ZoomInfo Technologies Inc. (Z2IT34)
# [4][1][448] - Zscaler, Inc. (Z2SC34)
# [4][1][449] - iQIYI, Inc. (I1QY34)
# [4][1][450] - iShares Trust (DOLL39)
# [4][1][451] - iShares Trust - iShares China Large-Cap ETF (BFXI39)
# [4][1][452] - iShares Trust - iShares Currency Hedged MSCI EAFE ETF (BHEF39)
# [4][1][453] - iShares Trust - iShares Europe ETF (BIEV39)
# [4][1][454] - iShares Trust - iShares Global REIT ETF (BGRT39)
# [4][1][455] - iShares Trust - iShares MSCI EAFE Growth ETF (BEFG39)
# [4][1][456] - iShares Trust - iShares MSCI EAFE Value ETF (BEFV39)
# [4][1][457] - iShares Trust - iShares MSCI USA Momentum Factor ETF (BMTU39)
# [4][1][458] - iShares Trust - iShares MSCI USA Quality Factor ETF (BQUA39)
# [4][1][459] - iShares Trust - iShares S&P 100 ETF (BOEF39)
# [4][1][460] - iShares Trust - iShares S&P 500 Growth ETF (BIVW39)
# [4][1][461] - iShares Trust - iShares S&P 500 Value ETF (BIVE39)
# [4][1][462] - iShares Trust - iShares U.S. Energy ETF (BIYE39)
# [4][1][463] - iShares Trust - iShares U.S. Medical Devices ETF (BIHI39)
# [4][1][464] - iShares Trust - iShares iBoxx $ High Yield Corporate Bond ETF (BHYG39)
# [4][1][465] - iShares Trust - iShares iBoxx $ Investment Grade Corporate Bond ETF (BLQD39)
# [4][1][466] - iShares, Inc. - iShares MSCI Canada ETF (BEWC39)
# [4][1][467] - iShares, Inc. - iShares MSCI Global Min Vol Factor ETF (BCWV39)
# [4][1][468] - iShares, Inc. - iShares MSCI Switzerland ETF (BEWL39)
# [4][1][469] - lululemon athletica inc. (L1UL34)
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# [4][2] - Fundos de Investimento e ETF
# [4][2][0] - Alupar Investimento S.A. (ALUP11)
# [4][2][1] - Az Quest Sole Fundo De Investimento Nas Cadeias Produtivas Do Agronegocio - Fiagro - Imobiliario (AAZQ11)
# [4][2][2] - B-Index Morningstar Setores Defensivos Brasil Fundo De Indice (BDEF11)
# [4][2][3] - BR Advisory Partners Participações S.A. (BRBI11)
# [4][2][4] - BTG Pactual Teva Debentures Di Fundo De Indice (DEBB11)
# [4][2][5] - Banco BTG Pactual S.A. (BPAC11)
# [4][2][6] - Banco Santander (Brasil) S.A. (SANB11)
# [4][2][7] - Bb Etf Ibovespa Fundo De Indice (BBOV11)
# [4][2][8] - Bocaina Infra- Fundo de Investimento em Cotas de Fundos Incentivados de Investimento em (BODB11)
# [4][2][9] - Btg Pactual Real Estate Hedge Fund Fii Fundo De Investimento Imobiliario (BTHF11)
# [4][2][10] - Capitania Agro Strategies - Fiagro - Imobiliario Fund (CPTR11)
# [4][2][11] - Capitania HBC Renda Urbana Fundo De Investimento Imobiliario (CPUR11)
# [4][2][12] - Capitania Malls Fundo De Investimento Imobiliario (AJFI11)
# [4][2][13] - Capitania Securities II Fundo Investimento Imobiliario FII (CPTS11)
# [4][2][14] - Capitania Shoppings Fundo De Investimento Imobiliario (CPSH11)
# [4][2][15] - Companhia de Saneamento do Paraná - SANEPAR (SAPR11)
# [4][2][16] - Cyrela Credito - Fundo De Investimento Imobiliario (CYCR11)
# [4][2][17] - Emet Multiestrategia Fundo De Investimento I Mobiliario Responsabilidade Limitada (EMET11)
# [4][2][18] - Energisa S.A. (ENGI11)
# [4][2][19] - FII DAMA    CI (DAMA11)
# [4][2][20] - FII MCLO    CI (MCLO11)
# [4][2][21] - FII VRTM    CI (VRTM11)
# [4][2][22] - Fundo De Investimento Nas Cadeias Produtivas Agroindustriais Riza Agro - Fiagro - Imobiliario (RZAG11)
# [4][2][23] - Fundo Infestimento Imobiliario Btg Pactual Credito Imobiliario (BTCI11)
# [4][2][24] - Fundo Investimento Imobiliario Rbr Alpha Fundos De Fundos (RBRF11)
# [4][2][25] - Fundo de Investimento Amazônia - FINAM (FNAM11)
# [4][2][26] - Ggr Covipe Renda Fundo Investimento Imobiliario (GGRC11)
# [4][2][27] - Guardian Logistica Fundo De Investimento Imobiliario (GARE11)
# [4][2][28] - Hashdex Nasdaq Crypto Index Fundo De Indice (HASH11)
# [4][2][29] - Hashdex Nasdaq Ethereum Reference Price Fundo De Indice (ETHE11)
# [4][2][30] - Hectare Recebiveis High Grade Fundo De Investimento Imobiliario  Fii (HCHG11)
# [4][2][31] - Hedge Real Estate I Fundo De Investimento Imobliario (HPDP11)
# [4][2][32] - INFRACOMM   DM    1,00 (IFCM11)
# [4][2][33] - IT Now S&P 500 Futures Quanto Brl Fundo De Indice - Responsabilidade Limitada (SPXR11)
# [4][2][34] - Iguatemi S.A. (IGTI11)
# [4][2][35] - Investo Etf Marketvector Brazil Treasury 760 Day Target Duration Classe De Indice - Responsab Limita (LFTB11)
# [4][2][36] - Investo Teva Tesouro Selic Etf - Fundo De Investimento De Indice (LFTS11)
# [4][2][37] - It Now IDIV Index Fund (DIVO11)
# [4][2][38] - It Now Ibovespa Fundo de Indice (BOVV11)
# [4][2][39] - It Now Nyse Fang+ Fundo De Indice (TECK11)
# [4][2][40] - Itau Asset Rural Fiagro - Imobiliario (RURA11)
# [4][2][41] - Kinea Securities Fundo De Investimento Imobiliario – Fii (KNSC11)
# [4][2][42] - Klabin S.A. (KLBN11)
# [4][2][43] - Manati Capital Hedge Fund Fundo De Investimento Imobiliario (MANA11)
# [4][2][44] - Maua Capital Real Estate Fundo De Investimento Imobiliario (MCRE11)
# [4][2][45] - Maxi Renda Fundo De Investimento Imobiliaro - FII (MXRF11)
# [4][2][46] - Polo Fundo de Investimento Imobiliário - Recebíveis Imobiliários II - FII (PORD11)
# [4][2][47] - Qr Cme Cf Bitcoin Reference Rate Fundo De Indice Investimento No Exterior (QBTC11)
# [4][2][48] - Qr Cme Cf Ether Reference Rate Fundo De Indice Investimento No Exterior (QETH11)
# [4][2][49] - Qr Cme Cf Solana Dollar Reference Rate Fundo De Índice Investimento No Exterior Respons Limitada (QSOL11)
# [4][2][50] - Santander Renda De Alugueis Fundo Investimento Imobiliarios (SARE11)
# [4][2][51] - Suno Agro - Fiagro-Imobiliario (SNAG11)
# [4][2][52] - Transmissora Aliança de Energia Elétrica S.A. (TAEE11)
# [4][2][53] - Trend ETF Ibovespa Fundo De Indice (BOVX11)
# [4][2][54] - Trend Etf Crsp Us Large Cap Fiim Ie (USAL11)
# [4][2][55] - Trend Etf Lbma Ouro Fundo Investimento Cotas De Fundo De Andice Investimento Exterior (GOLD11)
# [4][2][56] - Trend Etf Msci China Fundo De Indice (XINA11)
# [4][2][57] - Trend Etf Nasdaq 100 Fundo De Investimento De Indice - Investimento No Exterior (NASD11)
# [4][2][58] - Valora Cra Fundo De Investimento In Agroindustrial Production Chains - Fiagro-Imobiliário (VGIA11)
# [4][2][59] - Valora Hedge Fund Fundo De Investimento Imobiliario - Fii (VGHF11)
# [4][2][60] - Valora Re III Fundo De Investimento Imobiliario (VGIR11)
# [4][2][61] - Vinci Corporate Fundo De Investimento Imobiliario (VINO11)
# [4][2][62] - Xp Malls Fundo Investimentos Imobiliarios (XPML11)
# [4][2][63] - iShares BM&FBovespa Small Cap Fundo de Índice (SMAL11)
# [4][2][64] - iShares Ibovespa Index Fund (BOVA11)
# [4][2][65] - iShares S&P 500 Fundo de Investimento - Investimento No Exterior (IVVB11)
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=

# %% [markdown]
# ##[5]

# %%
n0 = 5

print("-="*20)
print(f"[{n0}] - {grpFin['nome']}")
print("-="*20)

# Verifica se grpB3 tem a chave 'lista'
if 'lista' in grpFin:
    for n1, t in enumerate(grpFin['lista']):
        print(f"[{n0}][{n1}] - {t['nome']}")

        # Verifica se t tem a chave 'lista' antes de tentar iterar
        if 'lista' in t:
            for n2, s in enumerate(t['lista']):
                print(f"[{n0}][{n1}][{n2}] - {s['nome']}")

        print("-="*20)
# Out:
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# [5] - Análise Financeira das empresas
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# [5][0] - Empresas Brasileiras (listadas na B3)
# [5][0][0] - ATMA Participações S.A. (ATMP3)
# [5][0][1] - ATOM EDUC   ON (ATED3)
# [5][0][2] - AUTOMOB     ON      NM (AMOB3)
# [5][0][3] - Aeris Indústria e Comércio de Equipamentos para Geração de Energia S.A. (AERI3)
# [5][0][4] - AgroGalaxy Participações S.A. (AGXY3)
# [5][0][5] - Alliança Saúde e Participações S.A. (AALR3)
# [5][0][6] - Allied Tecnologia S.A. (ALLD3)
# [5][0][7] - Allos S.A. (ALOS3)
# [5][0][8] - Allpark Empreendimentos, Participações e Serviços S.A. (ALPK3)
# [5][0][9] - Alpargatas S.A. (ALPA4)
# [5][0][10] - Alphaville S.A. (AVLL3)
# [5][0][11] - Alupar Investimento S.A. (ALUP4)
# [5][0][12] - Ambev S.A. (ABEV3)
# [5][0][13] - Ambipar Participações e Empreendimentos S.A. (AMBP3)
# [5][0][14] - Americanas S.A. (AMER3)
# [5][0][15] - Armac Locação, Logística e Serviços S.A. (ARML3)
# [5][0][16] - Atacadão S.A. (CRFB3)
# [5][0][17] - Auren Energia S.A. (AURE3)
# [5][0][18] - Azevedo & Travassos Energia S.A. (AZTE3)
# [5][0][19] - Azevedo & Travassos S.A. (AZEV4)
# [5][0][20] - Azul S.A. (AZUL4)
# [5][0][21] - Azzas 2154 S.A. (AZZA3)
# [5][0][22] - B3 S.A. - Brasil, Bolsa, Balcão (B3SA3)
# [5][0][23] - BB Seguridade Participações S.A. (BBSE3)
# [5][0][24] - BRB - Banco de Brasília S.A. (BSLI3)
# [5][0][25] - BRF S.A. (BRFS3)
# [5][0][26] - BRISANET    ON      NM (BRST3)
# [5][0][27] - Banco ABC Brasil S.A. (ABCB4)
# [5][0][28] - Banco BMG S.A. (BMGB4)
# [5][0][29] - Banco BTG Pactual S.A. (BPAC3)
# [5][0][30] - Banco Bradesco S.A. (BBDC4)
# [5][0][31] - Banco Mercantil do Brasil S.A. (BMEB4)
# [5][0][32] - Banco Pan S.A. (BPAN4)
# [5][0][33] - Banco Pine S.A. (PINE4)
# [5][0][34] - Banco Santander (Brasil) S.A. (SANB4)
# [5][0][35] - Banco da Amazônia S.A. (BAZA3)
# [5][0][36] - Banco do Brasil S.A. (BBAS3)
# [5][0][37] - Banco do Estado do Rio Grande do Sul S.A. (BRSR3)
# [5][0][38] - Banestes S.A - Banco do Estado do Espírito Santo (BEES3)
# [5][0][39] - Bemobi Mobile Tech S.A. (BMOB3)
# [5][0][40] - Bicicletas Monark S.A. (BMKS3)
# [5][0][41] - Biomm S.A. (BIOM3)
# [5][0][42] - Blau Farmacêutica S.A. (BLAU3)
# [5][0][43] - Boa Safra Sementes S.A. (SOJA3)
# [5][0][44] - Bombril S.A. (BOBR4)
# [5][0][45] - Bradespar S.A. (BRAP4)
# [5][0][46] - BrasilAgro - Companhia Brasileira de Propriedades Agrícolas (AGRO3)
# [5][0][47] - Braskem S.A. (BRKM3)
# [5][0][48] - Brava Energia S.A. (BRAV3)
# [5][0][49] - C&A Modas S.A. (CEAB3)
# [5][0][50] - CCR S.A. (CCRO3)
# [5][0][51] - CM Hospitalar S/A (VVEO3)
# [5][0][52] - CPFL Energia S.A. (CPFE3)
# [5][0][53] - CSN Mineração S.A. (CMIN3)
# [5][0][54] - CSU Digital S.A. (CSUD3)
# [5][0][55] - CVC Brasil Operadora e Agência de Viagens S.A. (CVCB3)
# [5][0][56] - Caixa Seguridade Participações S.A. (CXSE3)
# [5][0][57] - Cambuci S.A. (CAMB3)
# [5][0][58] - Camil Alimentos S.A. (CAML3)
# [5][0][59] - Centrais Elétricas Brasileiras S.A. - Eletrobrás (ELET3)
# [5][0][60] - Centrais Elétricas de Santa Catarina S.A. (CLSC4)
# [5][0][61] - Cia de Ferro Ligas da Bahia S.A. - FERBASA (FESA4)
# [5][0][62] - Cogna Educação S.A. (COGN3)
# [5][0][63] - Companhia Brasileira De Distribuicao (PCAR3)
# [5][0][64] - Companhia Brasileira de Alumínio (CBAV3)
# [5][0][65] - Companhia Energética de Brasília - CEB (CEBR3)
# [5][0][66] - Companhia Energética de Minas Gerais - CEMIG (CMIG4)
# [5][0][67] - Companhia Paranaense de Energia - COPEL (CPLE3)
# [5][0][68] - Companhia Siderúrgica Nacional (CSNA3)
# [5][0][69] - Companhia de Fiação e Tecidos Cedro e Cachoeira S.A. (CEDO4)
# [5][0][70] - Companhia de Saneamento Básico do Estado de São Paulo - SABESP (SBSP3)
# [5][0][71] - Companhia de Saneamento de Minas Gerais (CSMG3)
# [5][0][72] - Companhia de Saneamento do Paraná - SANEPAR (SAPR4)
# [5][0][73] - Construtora Tenda S.A. (TEND3)
# [5][0][74] - Cosan S.A. (CSAN3)
# [5][0][75] - Cruzeiro do Sul Educacional S.A. (CSED3)
# [5][0][76] - Cury Construtora e Incorporadora S.A. (CURY3)
# [5][0][77] - Cyrela Brazil Realty S.A. Empreendimentos e Participações (CYRE3)
# [5][0][78] - Desktop S.A. (DESK3)
# [5][0][79] - Dexco S.A. (DXCO3)
# [5][0][80] - Dexxos Participações S.A. (DEXP3)
# [5][0][81] - Diagnósticos da América S.A. (DASA3)
# [5][0][82] - Dimed S.A. Distribuidora de Medicamentos (PNVL3)
# [5][0][83] - Direcional Engenharia S.A. (DIRR3)
# [5][0][84] - Dotz S.A. (DOTZ3)
# [5][0][85] - EZTEC Empreendimentos e Participações S.A. (EZTC3)
# [5][0][86] - EcoRodovias Infraestrutura e Logística S.A. (ECOR3)
# [5][0][87] - Electro Aço Altona S.A. (EALT4)
# [5][0][88] - Eletromidia S.A. (ELMD3)
# [5][0][89] - Embpar Participacoes S.A. (EPAR3)
# [5][0][90] - Embraer S.A. (EMBR3)
# [5][0][91] - Empreendimentos Pague Menos S.A. (PGMN3)
# [5][0][92] - Empresa Metropolitana de Águas e Energia S.A. (EMAE4)
# [5][0][93] - Energisa S.A. (ENGI3)
# [5][0][94] - Eneva S.A. (ENEV3)
# [5][0][95] - Engie Brasil Energia S.A. (EGIE3)
# [5][0][96] - Enjoei S.A. (ENJU3)
# [5][0][97] - Equatorial Pará Distribuidora de Energia S.A. (EQPA3)
# [5][0][98] - Equatorial S.A. (EQTL3)
# [5][0][99] - Eternit S.A. (ETER3)
# [5][0][100] - Eucatex S.A. Indústria e Comércio (EUCA4)
# [5][0][101] - Even Construtora e Incorporadora S.A. (EVEN3)
# [5][0][102] - Fertilizantes Heringer S.A. (FHER3)
# [5][0][103] - Fictor Alimentos S.A. (FICT3)
# [5][0][104] - Fleury S.A. (FLRY3)
# [5][0][105] - Fras-le S.A. (FRAS3)
# [5][0][106] - GPS Participações e Empreendimentos S.A. (GGPS3)
# [5][0][107] - Gafisa S.A. (GFSA3)
# [5][0][108] - Gerdau S.A. (GGBR4)
# [5][0][109] - Gol Linhas Aéreas Inteligentes S.A. (GOLL4)
# [5][0][110] - Grazziotin S.A. (CGRA4)
# [5][0][111] - Grendene S.A. (GRND3)
# [5][0][112] - Grupo Casas Bahia S.A. (BHIA3)
# [5][0][113] - Grupo Mateus S.A. (GMAT3)
# [5][0][114] - Grupo SBF S.A. (SBFG3)
# [5][0][115] - Guararapes Confecções S.A. (GUAR3)
# [5][0][116] - HAGA S/A Indústria e Comércio (HAGA4)
# [5][0][117] - HBR Realty Empreendimentos Imobiliários S.A. (HBRE3)
# [5][0][118] - Hapvida Participações e Investimentos S.A. (HAPV3)
# [5][0][119] - Helbor Empreendimentos S.A. (HBOR3)
# [5][0][120] - Hidrovias do Brasil S.A. (HBSA3)
# [5][0][121] - Hospital Mater Dei S.A. (MATD3)
# [5][0][122] - Hotéis Othon S.A. (HOOT4)
# [5][0][123] - Hypera S.A. (HYPE3)
# [5][0][124] - IRB-Brasil Resseguros S.A. (IRBR3)
# [5][0][125] - ISA Energía Brasil S.A (ISAE4)
# [5][0][126] - Iguatemi S.A. (IGTI3)
# [5][0][127] - Inepar S.A. Indústria e Construções (INEP3)
# [5][0][128] - Infracommerce CXaaS S.A. (IFCM3)
# [5][0][129] - Intelbras S.A. - Indústria de Telecomunicação Eletrônica Brasileira (INTB3)
# [5][0][130] - International Meal Company Alimentação S.A. (MEAL3)
# [5][0][131] - Iochpe-Maxion S.A. (MYPK3)
# [5][0][132] - Irani Papel e Embalagem S.A. (RANI3)
# [5][0][133] - Itaú Unibanco Holding S.A. (ITUB4)
# [5][0][134] - Itaúsa S.A. (ITSA4)
# [5][0][135] - JBS S.A. (JBSS3)
# [5][0][136] - JHSF Participações S.A. (JHSF3)
# [5][0][137] - JSL S.A. (JSLG3)
# [5][0][138] - Jalles Machado S/A (JALL3)
# [5][0][139] - Kepler Weber S.A. (KEPL3)
# [5][0][140] - Klabin S.A. (KLBN4)
# [5][0][141] - LOG Commercial Properties e Participações S.A. (LOGG3)
# [5][0][142] - LPS Brasil - Consultoria de Imóveis S.A. (LPSB3)
# [5][0][143] - Lavvi Empreendimentos Imobiliários S.A. (LAVV3)
# [5][0][144] - Light S.A. (LIGT3)
# [5][0][145] - Livetech da Bahia Indústria e Comércio S.A. (LVTC3)
# [5][0][146] - Localiza Rent a Car S.A. (RENT3)
# [5][0][147] - Locaweb Serviços de Internet S.A. (LWSA3)
# [5][0][148] - Log-In Logística Intermodal S.A. (LOGN3)
# [5][0][149] - Lojas Quero-Quero S.A. (LJQQ3)
# [5][0][150] - Lojas Renner S.A. (LREN3)
# [5][0][151] - Lupatech S.A. (LUPA3)
# [5][0][152] - M. Dias Branco S.A. Indústria e Comércio de Alimentos (MDIA3)
# [5][0][153] - MAHLE Metal Leve S.A. (LEVE3)
# [5][0][154] - METISA Metalúrgica Timboense S.A. (MTSA4)
# [5][0][155] - MPM Corpóreos S.A. (ESPA3)
# [5][0][156] - MRV Engenharia e Participações S.A. (MRVE3)
# [5][0][157] - Magazine Luiza S.A. (MGLU3)
# [5][0][158] - Mangels Industrial S.A. (MGEL4)
# [5][0][159] - Marcopolo S.A. (POMO4)
# [5][0][160] - Marfrig Global Foods S.A. (MRFG3)
# [5][0][161] - Marisa Lojas S.A. (AMAR3)
# [5][0][162] - Melnick Desenvolvimento Imobiliário S.A. (MELK3)
# [5][0][163] - Metalurgica Gerdau S.A. (GOAU4)
# [5][0][164] - Metalúrgica Riosulense S.A. (RSUL4)
# [5][0][165] - Mills Locação, Serviços e Logística S.A. (MILS3)
# [5][0][166] - Minerva S.A. (BEEF3)
# [5][0][167] - Minupar Participações S.A. (MNPR3)
# [5][0][168] - Mitre Realty Empreendimentos e Participações S.A. (MTRE3)
# [5][0][169] - Mobly S.A. (MBLY3)
# [5][0][170] - Moura Dubeux Engenharia S.A. (MDNE3)
# [5][0][171] - Movida Participações S.A. (MOVI3)
# [5][0][172] - Multilaser Industrial S.A. (MLAS3)
# [5][0][173] - Multiplan Empreendimentos Imobiliários S.A. (MULT3)
# [5][0][174] - Méliuz S.A. (CASH3)
# [5][0][175] - Natura &Co Holding S.A. (NTCO3)
# [5][0][176] - Neoenergia S.A. (NEOE3)
# [5][0][177] - Neogrid Participações S.A. (NGRD3)
# [5][0][178] - Nexpe Participações S.A. (NEXP3)
# [5][0][179] - Nutriplant Indústria e Comércio S/A (NUTR3)
# [5][0][180] - OceanPact Serviços Marítimos S.A. (OPCT3)
# [5][0][181] - Odontoprev S.A. (ODPV3)
# [5][0][182] - Oi S.A. (OIBR3)
# [5][0][183] - Oncoclínicas do Brasil Serviços Médicos S.A. (ONCO3)
# [5][0][184] - Orizon Valorização de Resíduos S.A. (ORVR3)
# [5][0][185] - PBG S.A. (PTBL3)
# [5][0][186] - PDG Realty S.A. Empreendimentos e Participações (PDGR3)
# [5][0][187] - Padtec Holding S.A. (PDTC3)
# [5][0][188] - Paranapanema S.A. (PMAM3)
# [5][0][189] - Pet Center Comércio e Participações S.A. (PETZ3)
# [5][0][190] - Petroreconcavo S.A. (RECV3)
# [5][0][191] - Petróleo Brasileiro S.A. - Petrobras (PETR4)
# [5][0][192] - Pettenati S.A. Industria Têxtil (PTNT4)
# [5][0][193] - Plano & Plano Desenvolvimento Imobiliário S.A. (PLPL3)
# [5][0][194] - Porto Seguro S.A. (PSSA3)
# [5][0][195] - Positivo Tecnologia S.A. (POSI3)
# [5][0][196] - Priner Serviços Industriais S.A. (PRNR3)
# [5][0][197] - Prio S.A. (PRIO3)
# [5][0][198] - Profarma Distribuidora de Produtos Farmacêuticos S.A. (PFRM3)
# [5][0][199] - Qualicorp Consultoria e Corretora de Seguros S.A. (QUAL3)
# [5][0][200] - REAG Investimentos S.A. (REAG3)
# [5][0][201] - RNI Negócios Imobiliários S.A. (RDNI3)
# [5][0][202] - Raia Drogasil S.A. (RADL3)
# [5][0][203] - Randon S.A. Implementos e Participações (RAPT4)
# [5][0][204] - Raízen S.A. (RAIZ4)
# [5][0][205] - Recrusul S/A (RCSL4)
# [5][0][206] - Rede D'Or São Luiz S.A. (RDOR3)
# [5][0][207] - Refinaria de Petróleos de Manguinhos S.A. (RPMG3)
# [5][0][208] - Renova Energia S.A. (RNEW3)
# [5][0][209] - Rio Paranapanema Energia S.A. (GEPA3)
# [5][0][210] - Romi S.A. (ROMI3)
# [5][0][211] - Rossi Residencial S.A. (RSID3)
# [5][0][212] - Rumo S.A. (RAIL3)
# [5][0][213] - SIMPAR S.A. (SIMH3)
# [5][0][214] - SLC Agrícola S.A. (SLCE3)
# [5][0][215] - Santos Brasil Participações S.A. (STBP3)
# [5][0][216] - Schulz S.A. (SHUL4)
# [5][0][217] - Sendas Distribuidora S.A. (ASAI3)
# [5][0][218] - Sequoia Logística e Transportes S.A. (SEQL3)
# [5][0][219] - Ser Educacional S.A. (SEER3)
# [5][0][220] - Serena Energia S.A. (SRNA3)
# [5][0][221] - Smartfit Escola de Ginástica e Dança S.A. (SMFT3)
# [5][0][222] - Suzano S.A. (SUZB3)
# [5][0][223] - Syn Prop & Tech S.A. (SYNE3)
# [5][0][224] - São Carlos Empreendimentos e Participações S.A. (SCAR3)
# [5][0][225] - São Martinho S.A. (SMTO3)
# [5][0][226] - T4F Entretenimento S.A. (SHOW3)
# [5][0][227] - TC S.A. (TRAD3)
# [5][0][228] - TIM S.A. (TIMS3)
# [5][0][229] - TOTVS S.A. (TOTS3)
# [5][0][230] - Taurus Armas S.A. (TASA4)
# [5][0][231] - Technos S.A. (TECN3)
# [5][0][232] - Tecnisa S.A. (TCSA3)
# [5][0][233] - Tegma Gestão Logística S.A. (TGMA3)
# [5][0][234] - Telecomunicações Brasileiras S.A. - Telebras (TELB4)
# [5][0][235] - Telefônica Brasil S.A. (VIVT3)
# [5][0][236] - Terra Santa Propriedades Agrícolas S.A. (LAND3)
# [5][0][237] - Track & Field Co S.A. (TFCO4)
# [5][0][238] - Transmissora Aliança de Energia Elétrica S.A. (TAEE4)
# [5][0][239] - Trevisa Investimentos S.A. (LUXM4)
# [5][0][240] - Trisul S.A. (TRIS3)
# [5][0][241] - Triunfo Participações e Investimentos S.A. (TPIS3)
# [5][0][242] - Três Tentos Agroindustrial S/A (TTEN3)
# [5][0][243] - Tupy S.A. (TUPY3)
# [5][0][244] - Têxtil Renauxview S.A. (TXRX4)
# [5][0][245] - Ultrapar Participações S.A. (UGPA3)
# [5][0][246] - Unicasa Indústria de Móveis S.A. (UCAS3)
# [5][0][247] - Unifique Telecomunicações S.A. (FIQE3)
# [5][0][248] - Unipar Carbocloro S.A. (UNIP3)
# [5][0][249] - Usinas Siderúrgicas de Minas Gerais S.A. (USIM3)
# [5][0][250] - Vale S.A. (VALE3)
# [5][0][251] - Valid Soluções S.A. (VLID3)
# [5][0][252] - Vamos Locação de Caminhões, Máquinas e Equipamentos S.A. (VAMO3)
# [5][0][253] - Vibra Energia S.A. (VBBR3)
# [5][0][254] - Vitru Brasil Empreendimentos, Participações e Comércio S.A (VTRU3)
# [5][0][255] - Vittia S.A. (VITT3)
# [5][0][256] - Vivara Participações S.A. (VIVA3)
# [5][0][257] - Viver Incorporadora e Construtora S.A. (VIVR3)
# [5][0][258] - Vulcabras S.A. (VULC3)
# [5][0][259] - WEG S.A. (WEGE3)
# [5][0][260] - WLM Participações e Comércio de Máquinas e Veículos S.A. (WLMM4)
# [5][0][261] - Westwing Comércio Varejista S.A. (WEST3)
# [5][0][262] - Wetzel S.A. (MWET4)
# [5][0][263] - Wilson Sons S.A. (PORT3)
# [5][0][264] - Wiz Co Participações e Corretagem de Seguros S.A. (WIZC3)
# [5][0][265] - Yduqs Participações S.A. (YDUQ3)
# [5][0][266] - Zamp S.A. (ZAMP3)
# [5][0][267] - d1000 Varejo Farma Participações S.A. (DMVF3)
# [5][0][268] - Ânima Holding S.A. (ANIM3)
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# [5][1] - Empresas Estrangeiras (possuem BDRs)
# [5][1][0] - 3M Company (MMMC34)
# [5][1][1] - ABDEN SILV  DRE (SIVR39)
# [5][1][2] - ASML Holding N.V. (ASML34)
# [5][1][3] - AT&T Inc. (ATTB34)
# [5][1][4] - AbbVie Inc. (ABBV34)
# [5][1][5] - Abbott Laboratories (ABTT34)
# [5][1][6] - Accenture plc (ACNB34)
# [5][1][7] - Adobe Inc. (ADBE34)
# [5][1][8] - Advance Auto Parts, Inc. (A1AP34)
# [5][1][9] - Advanced Micro Devices, Inc. (A1MD34)
# [5][1][10] - Aegon Ltd. (A1EG34)
# [5][1][11] - Afya Limited (A2FY34)
# [5][1][12] - Airbnb, Inc. (AIRB34)
# [5][1][13] - Albemarle Corporation (A1LB34)
# [5][1][14] - Alexandria Real Estate Equities, Inc. (A1RE34)
# [5][1][15] - Alibaba Group Holding Limited (BABA34)
# [5][1][16] - Almacenes Éxito S.A. (EXCO32)
# [5][1][17] - Alphabet Inc. (GOGL34)
# [5][1][18] - Alphabet Inc. (GOGL35)
# [5][1][19] - Amazon.com, Inc. (AMZO34)
# [5][1][20] - American Airlines Group Inc. (AALL34)
# [5][1][21] - American Express Company (AXPB34)
# [5][1][22] - American Tower Corporation (T1OW34)
# [5][1][23] - American Water Works Company, Inc. (A1WK34)
# [5][1][24] - Annaly Capital Management, Inc. (N2LY34)
# [5][1][25] - Apple Inc. (AAPL34)
# [5][1][26] - Applied Materials, Inc. (A1MT34)
# [5][1][27] - ArcelorMittal S.A. (ARMT34)
# [5][1][28] - Archer-Daniels-Midland Company (A1DM34)
# [5][1][29] - Ares Management Corporation (A2RE34)
# [5][1][30] - Arista Networks Inc (A1NE34)
# [5][1][31] - AstraZeneca PLC (A1ZN34)
# [5][1][32] - Aura Minerals Inc. (AURA33)
# [5][1][33] - Autohome Inc. (A1TH34)
# [5][1][34] - Axon Enterprise, Inc. (A2XO34)
# [5][1][35] - BILL Holdings, Inc. (B2HI34)
# [5][1][36] - BKR 20YR TRSDRE (BTLT39)
# [5][1][37] - BKR 7 10 YRTDRE (BIYT39)
# [5][1][38] - BKR BITCOIN DRE (IBIT39)
# [5][1][39] - BKR CHILE   DRE (BECH39)
# [5][1][40] - BKR COMT ROLDRE (BCOM39)
# [5][1][41] - BKR ETHEREUMDRE (ETHA39)
# [5][1][42] - BKR FLOT RTEDRE (BTFL39)
# [5][1][43] - BKR GLOB100 DRE (BGLC39)
# [5][1][44] - BKR SHORT TRDRE (BSHV39)
# [5][1][45] - BKR TIP     DRE (BTIP39)
# [5][1][46] - BKR US TREASDRE (BGOV39)
# [5][1][47] - BP p.l.c. (B1PP34)
# [5][1][48] - BXP, Inc. (BOXP34)
# [5][1][49] - Baidu, Inc. (BIDU34)
# [5][1][50] - Banco Bilbao Vizcaya Argentaria, S.A. (BILB34)
# [5][1][51] - Banco Santander, S.A. (BCSA34)
# [5][1][52] - Banco Santander-Chile (B1SA34)
# [5][1][53] - Bancolombia S.A. (C2OL34)
# [5][1][54] - Bank of America Corporation (BOAC34)
# [5][1][55] - Barclays PLC (B1CS34)
# [5][1][56] - Berkshire Hathaway Inc. (BERK34)
# [5][1][57] - Beyond Meat, Inc. (B2YN34)
# [5][1][58] - Bio-Techne Corporation (T1CH34)
# [5][1][59] - BioNTech SE (B1NT34)
# [5][1][60] - BlackRock, Inc. (BLAK34)
# [5][1][61] - Block, Inc. (X1YZ34)
# [5][1][62] - Booking Holdings Inc. (BKNG34)
# [5][1][63] - Boston Scientific Corporation (B1SX34)
# [5][1][64] - Bread Financial Holdings, Inc. (A1LL34)
# [5][1][65] - Bristol-Myers Squibb Company (BMYB34)
# [5][1][66] - British American Tobacco p.l.c. (B1TI34)
# [5][1][67] - Broadcom Inc. (AVGO34)
# [5][1][68] - Brookfield Corporation (B1AM34)
# [5][1][69] - Burlington Stores, Inc. (B2UR34)
# [5][1][70] - CRISPR Therapeutics AG (C2RS34)
# [5][1][71] - CVS Health Corporation (CVSH34)
# [5][1][72] - Canadian National Railway Company (CNIC34)
# [5][1][73] - Canadian Pacific Kansas City Limited (CPRL34)
# [5][1][74] - Carnival Corporation & plc (C1CL34)
# [5][1][75] - Caterpillar Inc. (CATP34)
# [5][1][76] - Cerence Inc. (C2RN34)
# [5][1][77] - ChargePoint Holdings, Inc. (C2HP34)
# [5][1][78] - Charter Communications, Inc. (CHCM34)
# [5][1][79] - Chevron Corporation (CHVX34)
# [5][1][80] - Chipotle Mexican Grill, Inc. (C1MG34)
# [5][1][81] - Cisco Systems, Inc. (CSCO34)
# [5][1][82] - Citigroup Inc. (CTGP34)
# [5][1][83] - Citizens Financial Group, Inc. (C1FG34)
# [5][1][84] - Coinbase Global, Inc. (C2OI34)
# [5][1][85] - Colgate-Palmolive Company (COLG34)
# [5][1][86] - Comcast Corporation (CMCS34)
# [5][1][87] - ConocoPhillips (COPH34)
# [5][1][88] - Costco Wholesale Corporation (COWC34)
# [5][1][89] - Coursera, Inc. (C2OU34)
# [5][1][90] - Credicorp Ltd. (B2AP34)
# [5][1][91] - CrowdStrike Holdings, Inc. (C2RW34)
# [5][1][92] - Danaher Corporation (DHER34)
# [5][1][93] - Datadog, Inc. (D1DG34)
# [5][1][94] - Deere & Company (DEEC34)
# [5][1][95] - Dell Technologies Inc. (D1EL34)
# [5][1][96] - Deutsche Bank Aktiengesellschaft (DBAG34)
# [5][1][97] - DexCom, Inc. (D1EX34)
# [5][1][98] - Diageo plc (DEOP34)
# [5][1][99] - DocuSign, Inc. (D1OC34)
# [5][1][100] - Dollar General Corporation (DGCO34)
# [5][1][101] - Dow Inc. (D1OW34)
# [5][1][102] - Duke Energy Corporation (DUKB34)
# [5][1][103] - EVERTEC INC DR1 (EVTC31)
# [5][1][104] - Ecopetrol S.A. (E1CO34)
# [5][1][105] - Eli Lilly and Company (LILY34)
# [5][1][106] - Enphase Energy, Inc. (E2NP34)
# [5][1][107] - Equinix, Inc. (EQIX34)
# [5][1][108] - Equinor ASA (E1QN34)
# [5][1][109] - Essex Property Trust, Inc. (E1SS34)
# [5][1][110] - Etsy, Inc. (E2TS34)
# [5][1][111] - Expedia Group, Inc. (EXGR34)
# [5][1][112] - Exxon Mobil Corporation (EXXO34)
# [5][1][113] - Fair Isaac Corporation (F2IC34)
# [5][1][114] - First Solar, Inc. (FSLR34)
# [5][1][115] - Five9, Inc. (F2IV34)
# [5][1][116] - Fiverr International Ltd. (F2VR34)
# [5][1][117] - Ford Motor Company (FDMO34)
# [5][1][118] - Fortinet, Inc. (F1TN34)
# [5][1][119] - Franklin Resources, Inc. (F1RA34)
# [5][1][120] - Freeport-McMoRan Inc. (FCXO34)
# [5][1][121] - Freshworks Inc. (F2RS34)
# [5][1][122] - G2D Investments, Ltd. (G2DI33)
# [5][1][123] - GDS Holdings Limited (G1DS34)
# [5][1][124] - GE VERNOVA  DRN ED (G2EV34)
# [5][1][125] - GLOBANT SA  DRN (G1LO34)
# [5][1][126] - GP Investments, Ltd. (GPIV33)
# [5][1][127] - GSK plc (G1SK34)
# [5][1][128] - GX BLOCKCHAIDRE (BKCH39)
# [5][1][129] - GX CATHOLVALDRE (BCAT39)
# [5][1][130] - Galapagos NV (G1LP34)
# [5][1][131] - General Electric Company (GEOO34)
# [5][1][132] - General Mills, Inc. (G1MI34)
# [5][1][133] - General Motors Company (GMCO34)
# [5][1][134] - Global X Funds (BBUG39)
# [5][1][135] - Global X Funds (BCPX39)
# [5][1][136] - Global X Funds (BLBT39)
# [5][1][137] - Global X Funds (BOTZ39)
# [5][1][138] - Global X Funds (BQYL39)
# [5][1][139] - Global X Funds (BSDV39)
# [5][1][140] - Global X Funds (BSIL39)
# [5][1][141] - Global X Funds (BURA39)
# [5][1][142] - Globe Life Inc. (G1LL34)
# [5][1][143] - GoPro, Inc. (GPRO34)
# [5][1][144] - Gold Fields Limited (G1FI34)
# [5][1][145] - HEICO Corporation (H1EI34)
# [5][1][146] - HP Inc. (HPQB34)
# [5][1][147] - HSBC Holdings plc (H1SB34)
# [5][1][148] - Healthcare Realty Trust Incorporated (H2TA34)
# [5][1][149] - Healthpeak Properties, Inc. (P1EA34)
# [5][1][150] - Honda Motor Co., Ltd. (HOND34)
# [5][1][151] - Howmet Aerospace Inc. (ARNC34)
# [5][1][152] - HubSpot, Inc. (H2UB34)
# [5][1][153] - ING Groep N.V. (INGG34)
# [5][1][154] - Intel Corporation (ITLC34)
# [5][1][155] - Inter & Co, Inc. (INBR32)
# [5][1][156] - Intuitive Surgical, Inc. (I1SR34)
# [5][1][157] - Ishares Core Msci Europe ETF (BIEU39)
# [5][1][158] - Ishares Core S&P 500 Etf (BIVB39)
# [5][1][159] - Ishares Core S&P Small-Cap Etf (BIJR39)
# [5][1][160] - Ishares Core S&P Total Us Stock Market Etf (BITO39)
# [5][1][161] - Ishares Gold Trust (BIAU39)
# [5][1][162] - Ishares Msci Acwi ETF (BACW39)
# [5][1][163] - Ishares Msci All Country Asia Ex Japan ETF (BAAX39)
# [5][1][164] - Ishares Msci China Etf (BCHI39)
# [5][1][165] - Ishares Msci Eafe ETF (BEFA39)
# [5][1][166] - Ishares Msci Germany ETF (BEWG39)
# [5][1][167] - Ishares Msci Hong Kong Etf (BEWH39)
# [5][1][168] - Ishares Msci India Etf (BNDA39)
# [5][1][169] - Ishares Msci Japan Etf (BEWJ39)
# [5][1][170] - Ishares Msci Mexico ETF (BEWW39)
# [5][1][171] - Ishares Msci South Korea Etf (BEWY39)
# [5][1][172] - Ishares Russell 2000 Etf (BIWM39)
# [5][1][173] - Ishares Select Dividend Etf (BDVY39)
# [5][1][174] - Ishares Silver Trust (BSLV39)
# [5][1][175] - Ishares Trust Ishares Esg Aware Msci Usa ETF (BEGU39)
# [5][1][176] - Ishares US Technology ETF (BIYW39)
# [5][1][177] - Ishares Us Aerospace & Defense ETF (BAER39)
# [5][1][178] - JD.com, Inc. (JDCO34)
# [5][1][179] - JPMorgan Chase & Co. (JPMC34)
# [5][1][180] - Jefferies Financial Group Inc. (J1EF34)
# [5][1][181] - Johnson & Johnson (JNJB34)
# [5][1][182] - KR CSI CHINADRE (BKWB39)
# [5][1][183] - Kilroy Realty Corporation (K2RC34)
# [5][1][184] - Kinder Morgan, Inc. (KMIC34)
# [5][1][185] - Kingsoft Cloud Holdings Limited (K2CG34)
# [5][1][186] - LKR/SGD (BEWP39)
# [5][1][187] - Lennar Corporation (L1EN34)
# [5][1][188] - Lloyds Banking Group plc (L1YG34)
# [5][1][189] - Lockheed Martin Corporation (LMTB34)
# [5][1][190] - Lumen Technologies, Inc. (L1MN34)
# [5][1][191] - Luminar Technologies, Inc. (L2AZ34)
# [5][1][192] - LyondellBasell Industries N.V. (L1YB34)
# [5][1][193] - MP Materials Corp. (M2PM34)
# [5][1][194] - MSCI Inc. (M1SC34)
# [5][1][195] - Marsh & McLennan Companies, Inc. (M1MC34)
# [5][1][196] - Marvell Technology, Inc. (M2RV34)
# [5][1][197] - Mastercard Incorporated (MSCD34)
# [5][1][198] - McDonald's Corporation (MCDC34)
# [5][1][199] - Medical Properties Trust, Inc. (M2PW34)
# [5][1][200] - Melco Resorts & Entertainment Limited (M1LC34)
# [5][1][201] - MercadoLibre, Inc. (MELI34)
# [5][1][202] - Merck & Co., Inc. (MRCK34)
# [5][1][203] - Meta Platforms, Inc. (M1TA34)
# [5][1][204] - MicroStrategy Incorporated (M2ST34)
# [5][1][205] - Micron Technology, Inc. (MUTC34)
# [5][1][206] - Microsoft Corporation (MSFT34)
# [5][1][207] - Mitsubishi UFJ Financial Group, Inc. (M1UF34)
# [5][1][208] - Moderna, Inc. (M1RN34)
# [5][1][209] - Mondelez International, Inc. (MDLZ34)
# [5][1][210] - MongoDB, Inc. (M1DB34)
# [5][1][211] - Monolithic Power Systems, Inc. (M2PR34)
# [5][1][212] - Monster Beverage Corporation (M1NS34)
# [5][1][213] - NIKE, Inc. (NIKE34)
# [5][1][214] - NRG Energy, Inc. (N1RG34)
# [5][1][215] - NVIDIA Corporation (NVDC34)
# [5][1][216] - Nasdaq, Inc. (N1DA34)
# [5][1][217] - NatWest Group plc (N1WG34)
# [5][1][218] - NetApp, Inc. (N1TA34)
# [5][1][219] - Netflix, Inc. (NFLX34)
# [5][1][220] - Newell Brands Inc. (N1WL34)
# [5][1][221] - Newmont Corporation (N1EM34)
# [5][1][222] - NextEra Energy, Inc. (NEXT34)
# [5][1][223] - Nokia Oyj (NOKI34)
# [5][1][224] - Nomura Holdings, Inc. (NMRH34)
# [5][1][225] - Novo Nordisk A/S (N1VO34)
# [5][1][226] - Nu Holdings Ltd. (ROXO34)
# [5][1][227] - Nucor Corporation (N1UE34)
# [5][1][228] - O'Reilly Automotive, Inc. (ORLY34)
# [5][1][229] - ONEOK, Inc. (O1KE34)
# [5][1][230] - Occidental Petroleum Corporation (OXYP34)
# [5][1][231] - Oracle Corporation (ORCL34)
# [5][1][232] - PDD Holdings Inc. (P1DD34)
# [5][1][233] - PagSeguro Digital Ltd. (PAGS34)
# [5][1][234] - Palantir Technologies Inc. (P2LT34)
# [5][1][235] - Palo Alto Networks, Inc. (P2AN34)
# [5][1][236] - Patria Investments Limited (P2AX34)
# [5][1][237] - PayPal Holdings, Inc. (PYPL34)
# [5][1][238] - Penumbra, Inc. (P2NB34)
# [5][1][239] - PepsiCo, Inc. (PEPB34)
# [5][1][240] - Pfizer Inc. (PFIZ34)
# [5][1][241] - Pinterest, Inc. (P2IN34)
# [5][1][242] - Prologis, Inc. (P1LD34)
# [5][1][243] - Prudential Financial, Inc. (P1DT34)
# [5][1][244] - QUALCOMM Incorporated (QCOM34)
# [5][1][245] - RH (R2HH34)
# [5][1][246] - Realty Income Corporation (R1IN34)
# [5][1][247] - Regeneron Pharmaceuticals, Inc. (REGN34)
# [5][1][248] - Rio Tinto Group (RIOT34)
# [5][1][249] - Roblox Corporation (R2BL34)
# [5][1][250] - Roku, Inc. (R1KU34)
# [5][1][251] - SAP SE (SAPP34)
# [5][1][252] - SK Telecom Co., Ltd. (S1KM34)
# [5][1][253] - SL Green Realty Corp. (S1LG34)
# [5][1][254] - STAG Industrial, Inc. (S2TA34)
# [5][1][255] - Salesforce, Inc. (SSFO34)
# [5][1][256] - Sarepta Therapeutics, Inc. (S1RP34)
# [5][1][257] - Schlumberger Limited (SLBG34)
# [5][1][258] - Sea Limited (S2EA34)
# [5][1][259] - ServiceNow, Inc. (N1OW34)
# [5][1][260] - Shopify Inc. (S2HO34)
# [5][1][261] - Sibanye Stillwater Limited (S1BS34)
# [5][1][262] - Sigma Lithium Corporation (S2GM34)
# [5][1][263] - Simon Property Group, Inc. (SIMN34)
# [5][1][264] - Skyworks Solutions, Inc. (S1SL34)
# [5][1][265] - Snap Inc. (S2NA34)
# [5][1][266] - Snowflake Inc. (S2NW34)
# [5][1][267] - SolarEdge Technologies, Inc. (S2ED34)
# [5][1][268] - Sony Group Corporation (SNEC34)
# [5][1][269] - Spotify Technology S.A. (S1PO34)
# [5][1][270] - Sprouts Farmers Market, Inc. (S2FM34)
# [5][1][271] - Stanley Black & Decker, Inc. (S1WK34)
# [5][1][272] - Starbucks Corporation (SBUB34)
# [5][1][273] - StoneCo Ltd. (STOC34)
# [5][1][274] - Stride, Inc. (L2RN34)
# [5][1][275] - Sun Communities, Inc. (S2UI34)
# [5][1][276] - T-Mobile US, Inc. (T1MU34)
# [5][1][277] - TAL Education Group (T1AL34)
# [5][1][278] - Taiwan Semiconductor Manufacturing Company Limited (TSMC34)
# [5][1][279] - Take-Two Interactive Software, Inc. (T1TW34)
# [5][1][280] - Target Corporation (TGTB34)
# [5][1][281] - Teladoc Health, Inc. (T2DH34)
# [5][1][282] - Telefonaktiebolaget LM Ericsson (publ) (E1RI34)
# [5][1][283] - Telefónica, S.A. (TLNC34)
# [5][1][284] - Ternium S.A. (TXSA34)
# [5][1][285] - Tesla, Inc. (TSLA34)
# [5][1][286] - The AES Corporation (A1ES34)
# [5][1][287] - The Bank of New York Mellon Corporation (BONY34)
# [5][1][288] - The Boeing Company (BOEI34)
# [5][1][289] - The Charles Schwab Corporation (SCHW34)
# [5][1][290] - The Clorox Company (CLXC34)
# [5][1][291] - The Coca-Cola Company (COCA34)
# [5][1][292] - The Estée Lauder Companies Inc. (ELCI34)
# [5][1][293] - The Goldman Sachs Group, Inc. (GSGI34)
# [5][1][294] - The Home Depot, Inc. (HOME34)
# [5][1][295] - The Kraft Heinz Company (KHCB34)
# [5][1][296] - The PNC Financial Services Group, Inc. (PNCS34)
# [5][1][297] - The Procter & Gamble Company (PGCO34)
# [5][1][298] - The Progressive Corporation (P1GR34)
# [5][1][299] - The Sherwin-Williams Company (S1HW34)
# [5][1][300] - The Trade Desk, Inc. (T2TD34)
# [5][1][301] - The Walt Disney Company (DISB34)
# [5][1][302] - The Williams Companies, Inc. (W1MB34)
# [5][1][303] - Thermo Fisher Scientific Inc. (TMOS34)
# [5][1][304] - Toyota Motor Corporation (TMCO34)
# [5][1][305] - TransDigm Group Incorporated (T1DG34)
# [5][1][306] - Transocean Ltd. (RIGG34)
# [5][1][307] - Truist Financial Corporation (B1BT34)
# [5][1][308] - U.S. Bancorp (USBC34)
# [5][1][309] - UBS Group AG (UBSG34)
# [5][1][310] - Uber Technologies, Inc. (U1BE34)
# [5][1][311] - UiPath Inc. (P2AT34)
# [5][1][312] - Unilever PLC (ULEV34)
# [5][1][313] - United Airlines Holdings, Inc. (U1AL34)
# [5][1][314] - United Parcel Service, Inc. (UPSS34)
# [5][1][315] - UnitedHealth Group Incorporated (UNHH34)
# [5][1][316] - Unity Software Inc. (U2ST34)
# [5][1][317] - Upstart Holdings, Inc. (U2PS34)
# [5][1][318] - VeriSign, Inc. (VRSN34)
# [5][1][319] - Verizon Communications Inc. (VERZ34)
# [5][1][320] - Vertex Pharmaceuticals Incorporated (VRTX34)
# [5][1][321] - Visa Inc. (VISA34)
# [5][1][322] - Vodafone Group Public Limited Company (V1OD34)
# [5][1][323] - Walmart Inc. (WALM34)
# [5][1][324] - Warner Bros. Discovery, Inc. (W1BD34)
# [5][1][325] - Warner Music Group Corp. (W1MG34)
# [5][1][326] - Wayfair Inc. (W2YF34)
# [5][1][327] - Weibo Corporation (W1BO34)
# [5][1][328] - Wells Fargo & Company (WFCO34)
# [5][1][329] - Welltower Inc. (W1EL34)
# [5][1][330] - Whirlpool Corporation (W1HR34)
# [5][1][331] - Wix.com Ltd. (W1IX34)
# [5][1][332] - Wolfspeed, Inc. (W2OL34)
# [5][1][333] - XP Inc. (XPBR31)
# [5][1][334] - Xerox Holdings Corporation (XRXB34)
# [5][1][335] - YPF Sociedad Anónima (Y2PF34)
# [5][1][336] - Zoetis Inc. (Z1TS34)
# [5][1][337] - Zoom Communications Inc. (Z1OM34)
# [5][1][338] - iQIYI, Inc. (I1QY34)
# [5][1][339] - iShares Trust - iShares China Large-Cap ETF (BFXI39)
# [5][1][340] - iShares Trust - iShares Core Dividend Growth ETF (BGWH39)
# [5][1][341] - iShares Trust - iShares Core U.S. REIT ETF (BUSR39)
# [5][1][342] - iShares Trust - iShares Europe ETF (BIEV39)
# [5][1][343] - iShares Trust - iShares Global REIT ETF (BGRT39)
# [5][1][344] - iShares Trust - iShares MSCI USA Momentum Factor ETF (BMTU39)
# [5][1][345] - iShares Trust - iShares MSCI USA Quality Factor ETF (BQUA39)
# [5][1][346] - iShares Trust - iShares S&P 500 Growth ETF (BIVW39)
# [5][1][347] - iShares Trust - iShares S&P 500 Value ETF (BIVE39)
# [5][1][348] - iShares Trust - iShares Semiconductor ETF (BSOX39)
# [5][1][349] - iShares Trust - iShares U.S. Energy ETF (BIYE39)
# [5][1][350] - iShares Trust - iShares U.S. Medical Devices ETF (BIHI39)
# [5][1][351] - iShares Trust - iShares iBoxx $ High Yield Corporate Bond ETF (BHYG39)
# [5][1][352] - iShares, Inc. - iShares MSCI Canada ETF (BEWC39)
# [5][1][353] - iShares, Inc. - iShares MSCI Global Min Vol Factor ETF (BCWV39)
# [5][1][354] - iShares, Inc. - iShares MSCI World ETF (BURT39)
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=

# %% [markdown]
# ##[6]

# %%
n0 = 6
n1 = 0

print("-="*20)
print(f"[{n0}] - {grpCrip['nome']}")
print("-="*20)

for i in grpCrip['lista']:
      print(f"[{n0}][{n1}] - {i['nome']}")
      n1 += 1
print("-="*20)
# Out:
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# [6] - Criptomoedas
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# [6][0] - Bitcoin (BTC-USD)
# [6][1] - Ethereum (ETH-USD)
# [6][2] - Tether (USDT-USD)
# [6][3] - XRP (XRP-USD)
# [6][4] - BNB (BNB-USD)
# [6][5] - Solana (SOL-USD)
# [6][6] - USDC (USDC-USD)
# [6][7] - Dogecoin (DOGE-USD)
# [6][8] - Cardano (ADA-USD)
# [6][9] - TRON (TRX-USD)
# [6][10] - Lido Staked Ether (STETH-USD)
# [6][11] - Wrapped Bitcoin (WBTC-USD)
# [6][12] - Sui (SUI-USD)
# [6][13] - Chainlink (LINK-USD)
# [6][14] - Avalanche (AVAX-USD)
# [6][15] - Stellar (XLM-USD)
# [6][16] - LEO Token (LEO-USD)
# [6][17] - Shiba Inu (SHIB-USD)
# [6][18] - Toncoin (TON-USD)
# [6][19] - Hedera (HBAR-USD)
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=

# %% [markdown]
# #Interface

# %% [markdown]
# ## Principal

# %% [markdown]
# Executa o programa principal, listando todas as informações disponíveis e permitindo a escolha de apenas um dado por vez.
#
# **Obs:** Para agilizar a busca, recomenda-se consultar o Glossário e anotar a sequência de escolhas antes da execução.

# %%
print("-=" * 20)
print("Bem-vindo ao Alfa Scraps!")

g = pegaInfo()
if g[0] != grpCrip:
  g0,g1,g2 = g[0], g[1], g[2]
else:
  g0,g2 = g[0], g[1]

ntp = confereG2per(g2)

if g0 == grp[0]:
    dadof = criaDF_bcb(g1, g2["codigo"],ntp)

elif g0 == grp[1]:
    dadof = criaDF_fred(g2["codigo"])

elif g0 == grp[5]:
  dadof = dadosFincDF(g2["ticker"])

else:
    dadof = criaDF_yfinance(g2['ticker'], ntp)
    if dadof.empty:
      print("Nenhum dado encontrado para este ticker.")

# Salva os dados no CSV
criaCSV(dadof)
# Out:
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Bem-vindo ao Alfa Scraps!
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Informação #1
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# [0] Indicadores Macroeconômicos Brasil
# [1] Indicadores Macroeconômicos EUA
# [2] Commodities
# [3] Indices Globais da Bolsa de Valores
# [4] Acoes da B3
# [5] Análise Financeira das empresas
# [6] Criptomoedas
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Digite o número do grupo dos dados [-1 = sair]: 3
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Informação #2
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# [0] Gerais
# [1] Estados Unidos
# [2] Américas
# [3] Europa
# [4] Ásia & Oceania
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Digite o número do subgrupo do dado [-1 = voltar]: -1
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Voltando para o grupo anterior...
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Informação #1
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# [0] Indicadores Macroeconômicos Brasil
# [1] Indicadores Macroeconômicos EUA
# [2] Commodities
# [3] Indices Globais da Bolsa de Valores
# [4] Acoes da B3
# [5] Análise Financeira das empresas
# [6] Criptomoedas
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-b2baf189cdb8> in <cell line: 0>()
#       2 print("Bem-vindo ao Alfa Scraps!")
#       3
# ----> 4 g = pegaInfo()
#       5 if g[0] != grpCrip:
#       6   g0,g1,g2 = g[0], g[1], g[2]
#
# <ipython-input-65-1053fc76a05d> in pegaInfo()
#     156         # Chama a função do grupo atual, passando a resposta anterior, se houver
#     157         if grupo_atual == 0:
# --> 158             resposta = grupos[grupo_atual]()  # Para o primeiro grupo
#     159         elif grupo_atual == 1:
#     160             resposta = grupos[grupo_atual](resp[0])  # Para o segundo grupo
#
# <ipython-input-65-1053fc76a05d> in pegaInfo0()
#      22         listarDados(grp)
#      23         print("-="*20)
# ---> 24         entrada = input("Digite o número do grupo dos dados [-1 = sair]: ")
#      25         print("-="*20)
#      26
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ##Interface Express

# %% [markdown]
# * A **Interface Express** do **Alfa Scraps** permite que o usuário de forma rápida e eficiente selecione dados para análise utilizando uma abordagem simplificada. Com ela, você pode acessar dados específicos de grupos e subgrupos, realizando a análise sem precisar digitar os parâmetros completos.
#
# * O programa oferece uma interação simples no terminal, onde o usuário deve inserir um **grupo, subgrupo e dado** no formato `G,S,D` (Grupo, Subgrupo e Dado), separados por vírgulas.

# %%
def confere3Dados(d):
    resp = True  # Inicializando a variável com valor True

    # Verificando se a string contém exatamente duas vírgulas
    if "," not in d or d.count(",") != 2:
        resp = False
    else:
        # Separando os dados com a vírgula
        ld = d.split(",")

        # Remover qualquer espaço extra de cada item da lista
        ld = [i.strip() for i in ld]

        # Verificando condições de acordo com o tamanho da lista
        if len(ld) > 3 and int(ld[0]) != 5:
            resp = False
        elif len(ld) > 4:
            resp = False
        elif len(ld) == 4 and int(ld[0]) != 5:
            resp = False
        else:
            g0 = int(ld[0])
            if g0 < 0 or g0 > 6:
                resp = False
            else:
                g1 = int(ld[1])
                # Verificar se o grupo e subgrupo existem na estrutura
                if g0 == 6:
                    if g1 < 0 or g1 >= len(grpCrip["lista"]):
                        resp = False
                elif g0 == 5:
                    if g1 < 0 or g1 >= len(grpFin["lista"]):
                        resp = False
                    else:
                        g2 = int(ld[2])
                        if g2 < 0 or g2 >= len(grpFin["lista"][g1]["lista"]):
                            resp = False
                else:
                    if g1 < 0 or g1 >= len(grp[g0]["lista"]):
                        resp = False
                    else:
                        g2 = int(ld[2])
                        if g2 < 0 or g2 >= len(grp[g0]["lista"][g1]["lista"]):
                            resp = False

    return resp

def buscaDadoExpress():
    """
    Função para verificar se os dados fornecidos estão no formato esperado.
    O formato esperado é 'G,S,D' onde:
        - G: grupo (um número entre 0 e 6)
        - S: subgrupo (deve ser válido dentro do grupo)
        - D: dado (deve estar dentro do subgrupo)
    """
    dado = input("Digite o número do grupo, subgrupo e dado que deseja analisar (G,S,D):")

    while True:
        # Validação do dado fornecido
        if not confere3Dados(dado):
            print("Valor digitado inválido! Não esqueça de colocar vírgula depois das 2 primeiras informações.")
            print("Dúvida sobre os valores a serem digitados? Vá para o Glossário ou para a versão normal do Alfa Scraps.")
            dado = input("Digite o número do grupo, subgrupo e dado que deseja analisar (G,S,D):")
        else:
            break

    # Divisão do dado em grupo, subgrupo e dado
    dadoL = dado.split(",")
    dadoL = [i.strip() for i in dadoL]  # Removendo espaços extras

    g0, g1 = int(dadoL[0]), int(dadoL[1])  # Convertendo para inteiros

    # Retorna lista com os valores para cada tipo de grupo (G0)
    if g0 == 5:
        g2, n = int(dadoL[2]), 4
        return [g0, g1, g2, n]
    elif g0 == 6:
        n = 3
        return [g0, g1, 0, n]
    else:
        # Dependendo do grupo (G0), atribui valor a g2 e n
        if g0 == 0:
            g2, n = int(dadoL[2]), 1
        elif g0 == 1:
            g2, n = int(dadoL[2]), 2
        else:
            g2, n = int(dadoL[2]), 3
        return [g0, g1, g2, n]

def fazDfExpress(g1,g2,n,ntp):
  if n == 1:
    df = criaDF_bcb(g1, g2["codigo"],ntp)

  elif n == 2:
    df = criaDF_fred(g2["codigo"])

  elif n == 3:
    df = criaDF_yfinance(g2['ticker'],ntp)

  else:
    df = dadosFincDF(g2["ticker"])
  return df

# %%
print("-=" * 20)
print("Bem-vindo ao Alfa Scraps EXPRESS!")
print("-=" * 20)

dadoExp = buscaDadoExpress()
ntp = confereG2per(dadoExp[2])
g0 = grp[dadoExp[0]]
g1 = g0["lista"][dadoExp[1]]
if g0 != grpCrip:
  g2 = g1["lista"][dadoExp[2]]

dadof = fazDfExpress(g1,g2,dadoExp[3],ntp)
if dadof.empty:
    print(f"Nenhum dado encontrado para o ticker {g2} e o grupo {g0}.")
else:
    criaCSV(dadof)
# Out:
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Bem-vindo ao Alfa Scraps EXPRESS!
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Digite o número do grupo, subgrupo e dado que deseja analisar (G,S,D):5,1,96
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-27866a2cd89d> in <cell line: 0>()
#      10   g2 = g1["lista"][dadoExp[2]]
#      11
# ---> 12 dadof = fazDfExpress(g1,g2,dadoExp[3],ntp)
#      13 if dadof.empty:
#      14     print(f"Nenhum dado encontrado para o ticker {g2} e o grupo {g0}.")
#
# <ipython-input-47-a882e59617a3> in fazDfExpress(g1, g2, n, ntp)
#      99
#     100   else:
# --> 101     df = dadosFincDF(g2["ticker"])
#     102   return df
#     103
#
# TypeError: dadosFincDF() missing 1 required positional argument: 'tipod'
